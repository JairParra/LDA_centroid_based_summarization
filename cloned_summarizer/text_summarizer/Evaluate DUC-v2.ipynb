# %%
"""
Create LDA model using of DUC-2004 task 2 dataset
"""
import pickle
import LDA_extractor

# Load pickle containing DUC corpus
corpus = {}
with open('corpus.pkl', 'rb') as f:
        corpus = pickle.load(f)

# Create list of every article to train lda on
articles = []
for set_id in corpus.keys():
    articles = articles + corpus[set_id]['articles']

# %%
# Train LDA model on articles
parser = LDA_extractor.LDA_parser(articles,
                                  language='english', 
                                  preprocessor_type='spacy',
                                  num_topics = 32, 
                                  passes = 100,
                                  custom_filter = ['said'])

parser.print_topics(words_per_topic = 10) 
topic_mixtures = parser.extract_topics(max_words_per_topic=50, threshold=0.005)
print(topic_mixtures)

# extract topics as a dictionary
topics = parser.extract_topic_words(max_words_per_topic=50, threshold=0.005)
print(topics)
# Out:
# Initializing model...
#
# spaCy preprocessor selected.
# Fitting LDA topic modelling...
# Preprocessing corpus...
# Creating corpora dictionary...
# Translating doc2bow corpus...
# Running LDA...
#
# Done in 406.611 seconds.
# (4, '0.023*"said" + 0.010*"house" + 0.010*"republicans" + 0.009*"republican" + 0.008*"clinton" + 0.008*"people" + 0.008*"would" + 0.007*"gingrich" + 0.007*"president" + 0.006*"livingston"')
# (1, '0.015*"mail" + 0.012*"post" + 0.011*"office" + 0.010*"prize" + 0.008*"railroads" + 0.008*"academy" + 0.008*"nobel" + 0.007*"letters" + 0.005*"word" + 0.005*"carry"')
# (27, '0.018*"microsoft" + 0.009*"prize" + 0.008*"court" + 0.008*"case" + 0.007*"says" + 0.007*"courts" + 0.007*"antitrust" + 0.006*"justice" + 0.006*"consumers" + 0.006*"windows"')
# (22, '0.017*"hun" + 0.016*"sen" + 0.014*"said" + 0.010*"party" + 0.009*"government" + 0.008*"ranariddh" + 0.008*"opposition" + 0.006*"rainsy" + 0.006*"sam" + 0.006*"new"')
# (5, '0.026*"said" + 0.015*"kosovo" + 0.010*"milosevic" + 0.010*"president" + 0.009*"nato" + 0.008*"yugoslavia" + 0.007*"albanian" + 0.007*"army" + 0.007*"yugoslav" + 0.007*"holbrooke"')
# (14, '0.015*"said" + 0.013*"race" + 0.013*"lahoud" + 0.011*"hariri" + 0.009*"president" + 0.007*"prime" + 0.007*"minister" + 0.007*"monday" + 0.006*"lebanon" + 0.006*"seas"')
# (20, '0.015*"house" + 0.014*"said" + 0.013*"saramago" + 0.011*"prize" + 0.008*"budget" + 0.008*"white" + 0.008*"census" + 0.008*"nobel" + 0.007*"issues" + 0.007*"year"')
# (10, '0.030*"turkey" + 0.019*"said" + 0.019*"syria" + 0.014*"turkish" + 0.013*"kurdish" + 0.012*"yeltsin" + 0.012*"ocalan" + 0.011*"president" + 0.010*"military" + 0.008*"minister"')
# (13, '0.017*"said" + 0.015*"players" + 0.010*"minister" + 0.009*"sharon" + 0.008*"would" + 0.008*"government" + 0.007*"union" + 0.007*"foreign" + 0.007*"peace" + 0.006*"owners"')
# (17, '0.015*"said" + 0.013*"would" + 0.010*"oil" + 0.009*"abortion" + 0.007*"mobil" + 0.007*"exxon" + 0.006*"but" + 0.005*"companies" + 0.005*"like" + 0.005*"slepian"')
# (0, '0.011*"said" + 0.007*"plant" + 0.006*"anwar" + 0.005*"internet" + 0.005*"farrakhan" + 0.005*"police" + 0.005*"told" + 0.004*"local" + 0.004*"games" + 0.004*"bangkok"')
# (15, '0.014*"said" + 0.013*"food" + 0.012*"percent" + 0.011*"voinovich" + 0.009*"boyle" + 0.008*"children" + 0.007*"state" + 0.007*"years" + 0.006*"education" + 0.006*"mail"')
# (12, '0.031*"space" + 0.023*"station" + 0.015*"russian" + 0.010*"russia" + 0.010*"said" + 0.008*"international" + 0.008*"launch" + 0.008*"module" + 0.008*"new" + 0.007*"first"')
# (9, '0.043*"north" + 0.027*"korea" + 0.020*"said" + 0.015*"clinton" + 0.013*"nuclear" + 0.012*"korean" + 0.008*"south" + 0.007*"would" + 0.007*"kim" + 0.006*"united"')
# (21, '0.027*"said" + 0.019*"games" + 0.016*"ioc" + 0.012*"hodler" + 0.011*"committee" + 0.010*"salt" + 0.010*"lake" + 0.009*"olympic" + 0.008*"members" + 0.007*"bid"')
# (25, '0.022*"zarya" + 0.017*"endeavour" + 0.015*"astronauts" + 0.015*"unity" + 0.014*"shuttle" + 0.013*"control" + 0.013*"station" + 0.011*"mission" + 0.010*"space" + 0.009*"arm"')
# (24, '0.035*"microsoft" + 0.016*"netscape" + 0.009*"internet" + 0.009*"said" + 0.008*"government" + 0.008*"software" + 0.008*"browser" + 0.007*"would" + 0.007*"but" + 0.007*"case"')
# (28, '0.020*"said" + 0.013*"libya" + 0.010*"annan" + 0.009*"gadhafi" + 0.009*"libyan" + 0.009*"suspects" + 0.008*"bombing" + 0.007*"trial" + 0.005*"would" + 0.005*"people"')
# (8, '0.020*"airport" + 0.018*"palestinian" + 0.018*"israel" + 0.013*"palestinians" + 0.012*"security" + 0.012*"israeli" + 0.010*"plane" + 0.010*"officials" + 0.007*"authority" + 0.007*"said"')
# (18, '0.022*"commission" + 0.016*"said" + 0.014*"report" + 0.012*"south" + 0.010*"would" + 0.009*"euro" + 0.008*"anc" + 0.008*"apartheid" + 0.008*"rights" + 0.008*"amnesty"')
# {0: [('said', 0.010724975), ('plant', 0.0067478362), ('anwar', 0.006030119), ('internet', 0.005269557)], 1: [('mail', 0.014642172), ('post', 0.0121367825), ('office', 0.010865749), ('prize', 0.009979794), ('railroads', 0.008388594), ('academy', 0.008248034), ('nobel', 0.008054685), ('letters', 0.007359986), ('word', 0.0052757366), ('carry', 0.005088069), ('rubles', 0.005080699)], 2: [('government', 0.02840578), ('party', 0.026445586), ('prodi', 0.02444904), ('would', 0.011856191), ('vote', 0.011644444), ('parliament', 0.011528304), ('coalition', 0.011433863), ('center', 0.010945356), ('ecevit', 0.010519748), ('left', 0.0098067485), ('italy', 0.009554151), ('communist', 0.008971694), ('said', 0.00854762), ('yilmaz', 0.0079592345), ('support', 0.0075958413), ('premier', 0.007593324), ('new', 0.0074050585), ('confidence', 0.0073496285), ('political', 0.007121153), ('majority', 0.006875754), ('right', 0.006581441), ('minister', 0.006428224), ('form', 0.0060891686), ('elections', 0.006012127), ('could', 0.0059219073), ('wednesday', 0.005677763), ('leader', 0.0054815714), ('he', 0.0054639955), ('president', 0.005437036), ('last', 0.0050372574)], 3: [('bin', 0.021227034), ('laden', 0.02085778), ('said', 0.018433433), ('officials', 0.0073106186), ('terrorist', 0.0062887534), ('east', 0.005777387), ('united', 0.0056642317), ('afghanistan', 0.0055892076), ('states', 0.0053702733), ('evidence', 0.0053044846), ('government', 0.0051197796)], 4: [('said', 0.02280993), ('house', 0.0103299515), ('republicans', 0.010058837), ('republican', 0.008667236), ('clinton', 0.0077256383), ('people', 0.0077114305), ('would', 0.00761334), ('gingrich', 0.0067807017), ('president', 0.006509034), ('livingston', 0.006368345), ('party', 0.006100296), ('but', 0.005933214), ('fire', 0.0058672656), ('impeachment', 0.005396576), ('speaker', 0.0052567134)], 5: [('said', 0.025674738), ('kosovo', 0.015075557), ('milosevic', 0.010144634), ('president', 0.009666241), ('nato', 0.009411771), ('yugoslavia', 0.0077331164), ('albanian', 0.0074825385), ('army', 0.006996233), ('yugoslav', 0.006955406), ('holbrooke', 0.0067221248), ('military', 0.005294227), ('forces', 0.005180538), ('province', 0.005117345), ('serbian', 0.005047846)], 6: [('series', 0.023217347), ('yankees', 0.021681204), ('game', 0.012674171), ('world', 0.010115452), ('martinez', 0.009671589), ('right', 0.009346634), ('knoblauch', 0.008208438), ('ball', 0.008085689), ('padres', 0.007323451), ('williams', 0.0071481615), ('field', 0.0061971243), ('league', 0.005786356), ('left', 0.0056800796), ('pitches', 0.0052808225), ('stadium', 0.0052783797), ('first', 0.0052766465), ('saturday', 0.005133918), ('san', 0.005002577)], 7: [('said', 0.020159151), ('gay', 0.011536974), ('russia', 0.009397577), ('starovoitova', 0.008275033), ('officials', 0.0077467253), ('rights', 0.007392217), ('people', 0.0071751145), ('group', 0.006957031), ('chechnya', 0.0065873144), ('would', 0.00654774), ('president', 0.005950819), ('news', 0.0058619077), ('human', 0.00541314), ('endorsement', 0.005405953), ('petersburg', 0.005068302)], 8: [('airport', 0.020089597), ('palestinian', 0.018202659), ('israel', 0.017606052), ('palestinians', 0.01324939), ('security', 0.012152083), ('israeli', 0.011668057), ('plane', 0.01015191), ('officials', 0.009568923), ('authority', 0.0074403966), ('said', 0.0068491073), ('gaza', 0.00609007), ('aviation', 0.0053784274), ('anti', 0.0053503755), ('accords', 0.005325892)], 9: [('north', 0.04331385), ('korea', 0.027150003), ('said', 0.01997027), ('clinton', 0.015194648), ('nuclear', 0.012858287), ('korean', 0.011501258), ('south', 0.008198198), ('would', 0.0072312485), ('kim', 0.0067514977), ('united', 0.006397928), ('site', 0.0059571317), ('weapons', 0.00590899), ('koreans', 0.0055890684), ('states', 0.005492378), ('underground', 0.0050531407)], 10: [('turkey', 0.030177834), ('said', 0.019042172), ('syria', 0.018718416), ('turkish', 0.013737964), ('kurdish', 0.013157766), ('yeltsin', 0.01210669), ('ocalan', 0 ...
# {0: ['said', 'plant', 'anwar', 'internet'], 1: ['mail', 'post', 'office', 'prize', 'railroads', 'academy', 'nobel', 'letters', 'word', 'carry', 'rubles'], 2: ['government', 'party', 'prodi', 'would', 'vote', 'parliament', 'coalition', 'center', 'ecevit', 'left', 'italy', 'communist', 'said', 'yilmaz', 'support', 'premier', 'new', 'confidence', 'political', 'majority', 'right', 'minister', 'form', 'elections', 'could', 'wednesday', 'leader', 'he', 'president', 'last'], 3: ['bin', 'laden', 'said', 'officials', 'terrorist', 'east', 'united', 'afghanistan', 'states', 'evidence', 'government'], 4: ['said', 'house', 'republicans', 'republican', 'clinton', 'people', 'would', 'gingrich', 'president', 'livingston', 'party', 'but', 'fire', 'impeachment', 'speaker'], 5: ['said', 'kosovo', 'milosevic', 'president', 'nato', 'yugoslavia', 'albanian', 'army', 'yugoslav', 'holbrooke', 'military', 'forces', 'province', 'serbian'], 6: ['series', 'yankees', 'game', 'world', 'martinez', 'right', 'knoblauch', 'ball', 'padres', 'williams', 'field', 'league', 'left', 'pitches', 'stadium', 'first', 'saturday', 'san'], 7: ['said', 'gay', 'russia', 'starovoitova', 'officials', 'rights', 'people', 'group', 'chechnya', 'would', 'president', 'news', 'human', 'endorsement', 'petersburg'], 8: ['airport', 'palestinian', 'israel', 'palestinians', 'security', 'israeli', 'plane', 'officials', 'authority', 'said', 'gaza', 'aviation', 'anti', 'accords'], 9: ['north', 'korea', 'said', 'clinton', 'nuclear', 'korean', 'south', 'would', 'kim', 'united', 'site', 'weapons', 'koreans', 'states', 'underground'], 10: ['turkey', 'said', 'syria', 'turkish', 'kurdish', 'yeltsin', 'ocalan', 'president', 'military', 'minister', 'sunday', 'rebels', 'monday', 'he', 'also', 'demirel', 'pkk', 'border', 'kurds'], 11: ['said', 'tribunal', 'crimes', 'war', 'bosnian', 'serb', 'serbs', 'he', 'jelisic', 'trial', 'convicted', 'arrest', 'muslim', 'first'], 12: ['space', 'station', 'russian', 'russia', 'said', 'international', 'launch', 'module', 'new', 'first', 'shuttle', 'mir', 'nasa', 'friday', 'would', 'orbit', 'project', 'officials'], 13: ['said', 'players', 'minister', 'sharon', 'would', 'government', 'union', 'foreign', 'peace', 'owners', 'pinochet', 'israel', 'spanish', 'lockout', 'but', 'league'], 14: ['said', 'race', 'lahoud', 'hariri', 'president', 'prime', 'minister', 'monday', 'lebanon', 'seas', 'yacht', 'new', 'campbell', 'crew', 'yachts', 'south', 'missing', 'night'], 15: ['said', 'food', 'percent', 'voinovich', 'boyle', 'children', 'state', 'years', 'education', 'mail', 'malnutrition', 'last', 'red', 'former', 'cross', 'campaign'], 16: ['said', 'palestinian', 'israel', 'israeli', 'palestinians', 'netanyahu', 'clinton', 'east', 'peace', 'gaza', 'arafat', 'west'], 17: ['said', 'would', 'oil', 'abortion', 'mobil', 'exxon', 'but', 'companies'], 18: ['commission', 'said', 'report', 'south', 'would', 'euro', 'anc', 'apartheid', 'rights', 'amnesty', 'de', 'africa', 'mandela', 'president', 'human', 'truth', 'klerk', 'violations', 'political', 'national', 'bill', 'reconciliation', 'state', 'african', 'gross', 'could'], 19: ['said', 'anwar', 'economic', 'mahathir', 'percent', 'minister', 'would', 'government', 'imf'], 20: ['house', 'said', 'saramago', 'prize', 'budget', 'white', 'census', 'nobel', 'issues', 'year', 'spending', 'democrats', 'republicans', 'president'], 21: ['said', 'games', 'ioc', 'hodler', 'committee', 'lake', 'salt', 'olympic', 'members', 'bid', 'city', 'president', 'dlrs', 'samaranch', 'thai', 'asian', 'allegations'], 22: ['hun', 'sen', 'said', 'party', 'government', 'ranariddh', 'opposition', 'rainsy', 'sam', 'new', 'cambodia', 'people'], 23: ['shepard', 'said', 'gay', 'wyoming', 'hate', 'death', 'university', 'fence', 'people', 'student', 'family', 'casper', 'crimes', 'matthew', 'laws', 'laramie', 'violence', 'anti', 'homosexuals'], 24: ['microsoft', 'netscape', 'internet', 'said', 'government', 'software', 'browser', 'would', 'but', 'case', 'new', 'online', 'win ...

# %%
# Train LDA model on articles
parser100 = LDA_extractor.LDA_parser(articles,
                                  language='english', 
                                  preprocessor_type='spacy',
                                  num_topics = 100, 
                                  passes = 100,
                                  custom_filter = ['said'])

parser100.print_topics(words_per_topic = 20)
topic_mixtures = parser100.extract_topics(max_words_per_topic=50, threshold=0.005)
print(topic_mixtures)

# extract topics as a dictionary
topics = parser100.extract_topic_words(max_words_per_topic=50, threshold=0.005)
print(topics)
# Out:
# Initializing model...
#
# spaCy preprocessor selected.
# Fitting LDA topic modelling...
# Preprocessing corpus...
# Creating corpora dictionary...
# Translating doc2bow corpus...
# Running LDA...

# %%
import centroid_bow
import centroid_word_embeddings
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile

# %% [markdown]
# ## Evaluate using Word Embeddings Trained on Common Texts (dim = 100)

# %%
model = Word2Vec(common_texts, size=100, window=5, min_count=1, workers=-1) 
summarizer = centroid_word_embeddings.CentroidWordEmbeddingsSummarizer(model, parser = parser)

# %%
SET_ID = 0
compound_article = ''.join(corpus[list(corpus.keys())[SET_ID]]['articles'])
print(summarizer.summarize(compound_article))
# Out:
# [(22, 0.7596901), (5, 0.06407207), (4, 0.04172601), (30, 0.037221324), (11, 0.03537914), (16, 0.022312215), (14, 0.020064304)]
# Cambodian leader Hun Sen on Friday rejected opposition parties' demands for talks outside the country, accusing them of trying to ``internationalize'' the political crisis.
# Government and opposition parties have asked King Norodom Sihanouk to host a summit meeting after a series of post-election negotiations between the two opposition groups and Hun Sen's party to form a new government failed.
# Opposition leaders Prince Norodom Ranariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition figures after two alleged attempts on his life, said they could not negotiate freely in Cambodia and called for talks at Sihanouk's residence in Beijing.
# Hun Sen, however, rejected that.

# %%
import rouge_evaluator3
hypos = []
refs = []
for set_id in corpus.keys():
    hypos.append(summarizer.summarize(''.join(corpus[set_id]['articles'])))
    refs.append(corpus[set_id]['summaries'])
print(rouge_evaluator3.evaluate_hypotheses(hypos, refs))
# Out:
# [(22, 0.75968915), (5, 0.06407024), (4, 0.041724127), (30, 0.03721896), (11, 0.035378315), (16, 0.022312785), (14, 0.020062493)]
# [(19, 0.49437243), (28, 0.218518), (6, 0.13177569), (16, 0.055854514), (14, 0.028849889), (17, 0.02671278), (9, 0.022486668)]
# [(13, 0.3844263), (26, 0.34031698), (30, 0.08275041), (3, 0.06405593), (7, 0.04887628), (11, 0.046088208), (0, 0.013567894)]
# [(3, 0.77016616), (9, 0.051156893), (19, 0.04287122), (28, 0.03973539), (26, 0.03687236), (10, 0.023494856), (21, 0.015726412), (5, 0.013755593)]
# [(17, 0.55765146), (13, 0.31476828), (22, 0.036934745), (14, 0.036477376), (30, 0.02789569), (26, 0.014541828)]
# [(16, 0.77826595), (21, 0.105469756), (12, 0.042036407), (17, 0.026896121), (28, 0.022563789), (5, 0.012377378)]
# [(19, 0.7661774), (17, 0.07073686), (30, 0.026421214), (22, 0.02298948), (5, 0.020694094), (24, 0.019517487), (0, 0.016680181), (16, 0.015344771), (4, 0.014054547), (14, 0.012249647)]
# [(16, 0.6653408), (28, 0.2472496), (23, 0.07041405)]
# [(19, 0.60781205), (30, 0.10849229), (0, 0.085923865), (14, 0.07866984), (11, 0.03932604), (28, 0.031062255), (17, 0.018613743)]
# [(5, 0.8301067), (16, 0.13720903), (26, 0.026403055)]
# [(15, 0.31305286), (9, 0.31046882), (29, 0.10629227), (3, 0.05419535), (17, 0.044290952), (31, 0.03253034), (23, 0.031347502), (19, 0.025412755), (22, 0.022978853), (30, 0.017862922), (28, 0.015680837), (21, 0.015111392)]
# [(21, 0.50236136), (0, 0.105171494), (5, 0.104711704), (4, 0.07835533), (22, 0.07680675), (19, 0.027751798), (23, 0.024188535), (18, 0.01872938), (3, 0.017763553), (12, 0.01424255), (13, 0.012063862)]
# [(30, 0.809088), (24, 0.061781883), (19, 0.05455229), (4, 0.027887734), (28, 0.024622533)]
# [(4, 0.8298246), (9, 0.05142173), (18, 0.03875625), (16, 0.025213836), (21, 0.012882343), (6, 0.010929721)]
# [(24, 0.55486023), (29, 0.30335844), (12, 0.043081507), (15, 0.03159113), (23, 0.028857604), (4, 0.016384704)]
# [(19, 0.60285103), (17, 0.08998638), (24, 0.059132915), (29, 0.055391565), (1, 0.03767997), (18, 0.03656914), (5, 0.032150764), (4, 0.028333662), (21, 0.013981576), (3, 0.012389902)]
# [(10, 0.8600466), (13, 0.111547455), (5, 0.015655242)]
# [(14, 0.82422215), (11, 0.13329352), (6, 0.035190202)]
# [(25, 0.6155883), (12, 0.2896688), (24, 0.04851919), (26, 0.03219137), (23, 0.013783465)]
# [(22, 0.3396747), (19, 0.30108252), (18, 0.16494536), (31, 0.048122242), (17, 0.044389773), (28, 0.030476727), (0, 0.024243865), (23, 0.019889507), (4, 0.017418373)]
# [(16, 0.5666794), (3, 0.2757642), (15, 0.07026043), (9, 0.05057076), (30, 0.010329196)]
# [(20, 0.42388085), (22, 0.21896231), (27, 0.11403171), (29, 0.097196735), (14, 0.064532824), (1, 0.03756869), (4, 0.01807883), (13, 0.016235469)]
# [(16, 0.415501), (13, 0.34975255), (12, 0.09654695), (17, 0.038518418), (3, 0.03331306), (7, 0.028193926), (2, 0.020589573), (22, 0.014091543)]
# [(21, 0.91527116), (22, 0.026759971), (14, 0.023177292), (20, 0.020662563), (29, 0.011077779)]
# [(16, 0.72802484), (8, 0.19696058), (30, 0.046657935), (17, 0.023073858)]
# [(28, 0.789256), (25, 0.06382361), (0, 0.04448921), (5, 0.04114174), (4, 0.025387717), (26, 0.012725544), (29, 0.012451649)]
# [(10, 0.5936418), (28, 0.08967219), (30, 0.07219503), (19, 0.059120126), (6, 0.04728997), (11, 0.045537006), (24, 0.033073224), (2, 0.020308241), (9, 0.012190808), (22, 0.011213246)]
# [(17, 0.86975724), (24, 0.053647824), (19, 0.029251536), (13, 0.02399602), (0, 0.018632684)]
# [(4, 0.60509497), (17, 0.08612565), (5, 0.066348076), (30, 0.06467092), (9, 0.062239084), (3, 0.02950445), (21, 0.020531297), (8, 0.019643256), (6, 0.018711304)]
# [(12, 0.44348174), (25, 0.39970484), (24, 0.11393191), (26, 0.03235685)]
# [(19, 0.88403964), (4, 0.041469067), (31, 0.02907451), (18, 0.02326672), (24, 0.011286104)]
# [(9, 0.8219519), (19, 0.07471254), (29, 0.05408754), (3, 0.041620854)]
# [(7, 0.2659892), (4, 0.26035228), (15, 0.16812126), (23, 0.070347674), (30, 0.04544386), (16, 0.039507106), (17, 0.03588946), (26, 0.033389907), (24, 0.021787833), (28, 0.016465057), (3, 0.011946428), (5, 0.010318541)]
# [(11, 0.59427387), (19, 0.16846934), (5, 0.11257052), (16, 0.04892227), (4, 0.02681157), (22, 0.018880682), (15, 0.014507905), (30, 0.013031136)]
# [(16, 0.8153506), (5, 0.14152549), (17, 0.02418622)]
# [(2, 0.9049129), (5, 0.038582195), (23, 0.018772844), (25, 0.014397589)]
# [(7, 0.755998), (5, 0.16125), (29, 0.025915967), (16, 0.019105984), (4, 0.01240108), (10, 0.011555794)]
# [(7, 0.59152955), (30, 0.13860454), (4, 0.054161552), (16, 0.05178594), (12, 0.048357826), (20, 0.03037759), (10, 0.02087649), (3, 0.014787496), (19, 0.013911523), (27, 0.013409337)]
# [(18, 0.4398617), (4, 0.18278387), (13, 0.10028976), (29, 0.08821127), (7, 0.049190607), (26, 0.045071226), (30, 0.042535756), (11, 0.019247), (17, 0.01313368)]
# [(23, 0.49317494), (4, 0.30374005), (5, 0.0749621), (24, 0.061722398), (7, 0.059792057)]
# [(2, 0.38390937), (22, 0.19407034), (10, 0.18498279), (24, 0.0833953), (4, 0.07924051), (18, 0.038341478), (28, 0.012837029)]
# [(17, 0.7554107), (4, 0.04221243), (23, 0.041744735), (27, 0.03734825), (11, 0.032891028), (7, 0.03143889), (3, 0.018053297)]
# [(4, 0.9952203)]
# [(6, 0.4400345), (17, 0.26827127), (29, 0.09738278), (24, 0.0764102), (11, 0.05869579), (12, 0.043212008), (20, 0.0152877765)]
# [(20, 0.40293735), (4, 0.17277314), (18, 0.15697168), (30, 0.077813685), (3, 0.0549938), (17, 0.037086077), (24, 0.02381496), (19, 0.023637144), (26, 0.021325007), (29, 0.015534108)]
# [(10, 0.4972297), (5, 0.21388198), (19, 0.08393854), (7, 0.070584185), (3, 0.063623436), (4, 0.023294322), (29, 0.015503273), (2, 0.0129338475)]
# [(24, 0.6826695), (27, 0.20374678), (3, 0.044480752), (4, 0.020751445), (17, 0.013710688), (25, 0.012039757), (21, 0.011341139)]
# [(3, 0.5624995), (26, 0.27630806), (6, 0.05575227), (5, 0.053635918), (22, 0.031611715), (11, 0.015367988)]
# [(14, 0.644647), (5, 0.20464799), (16, 0.07126525), (26, 0.032978505), (10, 0.027950412), (2, 0.01687276)]
# [(30, 0.64442), (28, 0.0790782), (25, 0.055356983), (13, 0.044968847), (6, 0.043169796), (24, 0.03553585), (4, 0.034265626), (19, 0.022180494), (29, 0.012881858), (9, 0.011815096)]
# Evaluation with Avg
# 	metric:	P: 31.63	R: 31.85	F1: 31.74
# 	metric:	P:  6.39	R:  6.44	F1:  6.41
# 	metric:	P:  2.03	R:  2.05	F1:  2.04
# 	metric:	P:  0.81	R:  0.82	F1:  0.81
# 	metric:	P: 26.88	R: 27.04	F1: 26.96
# 	metric:	P: 13.97	R:  5.58	F1:  7.97
#
# Evaluation with Best
# 	metric:	P: 35.98	R: 36.29	F1: 36.13
# 	metric:	P: 10.20	R: 10.28	F1: 10.24
# 	metric:	P:  4.54	R:  4.58	F1:  4.56
# 	metric:	P:  2.42	R:  2.44	F1:  2.43
# 	metric:	P: 30.79	R: 31.05	F1: 30.91
# 	metric:	P: 16.75	R:  6.70	F1:  9.57
#
# Evaluation with Individual
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 42.31	R: 42.31	F1: 42.31
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 49.04	R: 50.00	F1: 49.51
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 42.31	R: 44.00	F1: 43.14
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 42.31	R: 43.56	F1: 42.93
# 	Hypothesis #1 & Reference #0:
# 		metric:	P: 30.30	R: 28.04	F1: 29.13
# 	Hypothesis #1 & Reference #1:
# 		metric:	P: 27.27	R: 25.47	F1: 26.34
# 	Hypothesis #1 & Reference #2:
# 		metric:	P: 26.26	R: 25.24	F1: 25.74
# 	Hypothesis #1 & Reference #3:
# 		metric:	P: 34.34	R: 32.38	F1: 33.33
# 	Hypothesis #2 & Reference #0:
# 		metric:	P: 33.66	R: 33.33	F1: 33.50
# 	Hypothesis #2 & Reference #1:
# 		metric:	P: 29.70	R: 29.41	F1: 29.56
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 37.62	R: 37.25	F1: 37.44
# 	Hypothesis #2 & Reference #3:
# 		metric:	P: 27.72	R: 28.87	F1: 28.28
# 	Hypothesis #3 & Reference #0:
# 		metric:	P: 29.81	R: 29.52	F1: 29.67
# 	Hypothesis #3 & Reference #1:
# 		metric:	P: 22.12	R: 22.55	F1: 22.33
# 	Hypothesis #3 & Reference #2:
# 		metric:	P: 21.15	R: 21.57	F1: 21.36
# 	Hypothesis #3 & Reference #3:
# 		metric:	P: 24.04	R: 24.27	F1: 24.15
# 	Hypothesis #4 & Reference #0:
# 		metric:	P: 27.45	R: 28.00	F1: 27.72
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 33.33	R: 34.00	F1: 33.66
# 	Hypothesis #4 & Reference #2:
# 		metric:	P: 27.45	R: 27.45	F1: 27.45
# 	Hypothesis #4 & Reference #3:
# 		metric:	P: 31.37	R: 31.07	F1: 31.22
# 	Hypothesis #5 & Reference #0:
# 		metric:	P: 30.69	R: 30.39	F1: 30.54
# 	Hypothesis #5 & Reference #1:
# 		metric:	P: 21.78	R: 22.22	F1: 22.00
# 	Hypothesis #5 & Reference #2:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #5 & Reference #3:
# 		metric:	P: 23.76	R: 23.53	F1: 23.65
# 	Hypothesis #6 & Reference #0:
# 		metric:	P: 31.19	R: 32.69	F1: 31.92
# 	Hypothesis #6 & Reference #1:
# 		metric:	P: 26.61	R: 28.71	F1: 27.62
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 37.61	R: 40.59	F1: 39.05
# 	Hypothesis #6 & Reference #3:
# 		metric:	P: 29.36	R: 30.77	F1: 30.05
# 	Hypothesis #7 & Reference #0:
# 		metric:	P: 34.62	R: 36.73	F1: 35.64
# 	Hypothesis #7 & Reference #1:
# 		metric:	P: 39.42	R: 41.41	F1: 40.39
# 	Hypothesis #7 & Reference #2:
# 		metric:	P: 32.69	R: 34.00	F1: 33.33
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 34.62	R: 36.36	F1: 35.47
# 	Hypothesis #8 & Reference #0:
# 		metric:	P: 29.41	R: 30.30	F1: 29.85
# 	Hypothesis #8 & Reference #1:
# 		metric:	P: 20.59	R: 20.19	F1: 20.39
# 	Hypothesis #8 & Reference #2:
# 		metric:	P: 26.47	R: 26.47	F1: 26.47
# 	Hypothesis #8 & Reference #3:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #9 & Reference #0:
# 		metric:	P: 25.00	R: 24.27	F1: 24.63
# 	Hypothesis #9 & Reference #1:
# 		metric:	P: 26.00	R: 26.00	F1: 26.00
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 33.00	R: 31.43	F1: 32.20
# 	Hypothesis #9 & Reference #3:
# 		metric:	P: 27.00	R: 26.21	F1: 26.60
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 35.24	R: 35.92	F1: 35.58
# 	Hypothesis #10 & Reference #1:
# 		metric:	P: 33.33	R: 34.31	F1: 33.82
# 	Hypothesis #10 & Reference #2:
# 		metric:	P: 29.52	R: 30.10	F1: 29.81
# 	Hypothesis #10 & Reference #3:
# 		metric:	P: 23.81	R: 25.00	F1: 24.39
# 	Hypothesis #11 & Reference #0:
# 		metric:	P: 31.37	R: 31.07	F1: 31.22
# 	Hypothesis #11 & Reference #1:
# 		metric:	P: 31.37	R: 32.00	F1: 31.68
# 	Hypothesis #11 & Reference #2:
# 		metric:	P: 23.53	R: 23.08	F1: 23.30
# 	Hypothesis #11 & Reference #3:
# 		metric:	P: 32.35	R: 31.73	F1: 32.04
# 	Hypothesis #12 & Reference #0:
# 		metric:	P: 31.73	R: 32.67	F1: 32.20
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 35.58	R: 36.27	F1: 35.92
# 	Hypothesis #12 & Reference #2:
# 		metric:	P: 26.92	R: 27.72	F1: 27.32
# 	Hypothesis #12 & Reference #3:
# 		metric:	P: 23.08	R: 23.30	F1: 23.19
# 	Hypothesis #13 & Reference #0:
# 		metric:	P: 34.65	R: 34.31	F1: 34.48
# 	Hypothesis #13 & Reference #1:
# 		metric:	P: 27.72	R: 27.45	F1: 27.59
# 	Hypothesis #13 & Reference #2:
# 		metric:	P: 31.68	R: 33.33	F1: 32.49
# 	Hypothesis #13 & Reference #3:
# 		metric:	P: 32.67	R: 31.73	F1: 32.20
# 	Hypothesis #14 & Reference #0:
# 		metric:	P: 24.53	R: 26.00	F1: 25.24
# 	Hypothesis #14 & Reference #1:
# 		metric:	P: 19.81	R: 22.11	F1: 20.90
# 	Hypothesis #14 & Reference #2:
# 		metric:	P: 29.25	R: 30.39	F1: 29.81
# 	Hypothesis #14 & Reference #3:
# 		metric:	P: 24.53	R: 25.49	F1: 25.00
# 	Hypothesis #15 & Reference #0:
# 		metric:	P: 15.45	R: 17.71	F1: 16.50
# 	Hypothesis #15 & Reference #1:
# 		metric:	P: 20.91	R: 23.00	F1: 21.90
# 	Hypothesis #15 & Reference #2:
# 		metric:	P: 11.82	R: 13.13	F1: 12.44
# 	Hypothesis #15 & Reference #3:
# 		metric:	P: 19.09	R: 20.59	F1: 19.81
# 	Hypothesis #16 & Reference #0:
# 		metric:	P: 27.36	R: 28.16	F1: 27.75
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 31.13	R: 32.67	F1: 31.88
# 	Hypothesis #16 & Reference #2:
# 		metric:	P: 33.02	R: 33.65	F1: 33.33
# 	Hypothesis #16 & Reference #3:
# 		metric:	P: 25.47	R: 26.47	F1: 25.96
# 	Hypothesis #17 & Reference #0:
# 		metric:	P: 33.98	R: 33.33	F1: 33.65
# 	Hypothesis #17 & Reference #1:
# 		metric:	P: 24.27	R: 24.27	F1: 24.27
# 	Hypothesis #17 & Reference #2:
# 		metric:	P: 27.18	R: 26.67	F1: 26.92
# 	Hypothesis #17 & Reference #3:
# 		metric:	P: 31.07	R: 29.91	F1: 30.48
# 	Hypothesis #18 & Reference #0:
# 		metric:	P: 36.89	R: 36.19	F1: 36.54
# 	Hypothesis #18 & Reference #1:
# 		metric:	P: 31.07	R: 32.00	F1: 31.53
# 	Hypothesis #18 & Reference #2:
# 		metric:	P: 35.92	R: 34.91	F1: 35.41
# 	Hypothesis #18 & Reference #3:
# 		metric:	P: 27.18	R: 26.92	F1: 27.05
# 	Hypothesis #19 & Reference #0:
# 		metric:	P: 34.95	R: 35.29	F1: 35.12
# 	Hypothesis #19 & Reference #1:
# 		metric:	P: 33.01	R: 33.66	F1: 33.33
# 	Hypothesis #19 & Reference #2:
# 		metric:	P: 25.24	R: 25.24	F1: 25.24
# 	Hypothesis #19 & Reference #3:
# 		metric:	P: 35.92	R: 35.58	F1: 35.75
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 36.89	R: 40.00	F1: 38.38
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 38.83	R: 39.60	F1: 39.22
# 	Hypothesis #20 & Reference #2:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #20 & Reference #3:
# 		metric:	P: 34.95	R: 36.00	F1: 35.47
# 	Hypothesis #21 & Reference #0:
# 		metric:	P: 27.72	R: 28.00	F1: 27.86
# 	Hypothesis #21 & Reference #1:
# 		metric:	P: 33.66	R: 33.33	F1: 33.50
# 	Hypothesis #21 & Reference #2:
# 		metric:	P: 24.75	R: 23.81	F1: 24.27
# 	Hypothesis #21 & Reference #3:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 42.86	R: 43.69	F1: 43.27
# 	Hypothesis #22 & Reference #1:
# 		metric:	P: 35.24	R: 36.27	F1: 35.75
# 	Hypothesis #22 & Reference #2:
# 		metric:	P: 37.14	R: 37.86	F1: 37.50
# 	Hypothesis #22 & Reference #3:
# 		metric:	P: 35.24	R: 37.00	F1: 36.10
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 44.00	R: 42.72	F1: 43.35
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 41.00	R: 41.00	F1: 41.00
# 	Hypothesis #23 & Reference #2:
# 		metric:	P: 39.00	R: 36.79	F1: 37.86
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 42.00	R: 41.18	F1: 41.58
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 42.00	R: 42.00	F1: 42.00
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 38.00	R: 38.00	F1: 38.00
# 	Hypothesis #24 & Reference #2:
# 		metric:	P: 32.00	R: 31.68	F1: 31.84
# 	Hypothesis #24 & Reference #3:
# 		metric:	P: 36.00	R: 34.62	F1: 35.29
# 	Hypothesis #25 & Reference #0:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #25 & Reference #1:
# 		metric:	P: 23.76	R: 24.00	F1: 23.88
# 	Hypothesis #25 & Reference #2:
# 		metric:	P: 26.73	R: 26.73	F1: 26.73
# 	Hypothesis #25 & Reference #3:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #26 & Reference #0:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 39.81	R: 43.16	F1: 41.41
# 	Hypothesis #26 & Reference #2:
# 		metric:	P: 43.69	R: 44.12	F1: 43.90
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 36.89	R: 38.00	F1: 37.44
# 	Hypothesis #27 & Reference #0:
# 		metric:	P: 41.75	R: 41.75	F1: 41.75
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 46.60	R: 46.15	F1: 46.38
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 46.60	R: 46.60	F1: 46.60
# 	Hypothesis #27 & Reference #3:
# 		metric:	P: 39.81	R: 39.81	F1: 39.81
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 36.63	R: 35.92	F1: 36.27
# 	Hypothesis #28 & Reference #1:
# 		metric:	P: 33.66	R: 35.42	F1: 34.52
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 38.61	R: 38.61	F1: 38.61
# 	Hypothesis #28 & Reference #3:
# 		metric:	P: 36.63	R: 35.24	F1: 35.92
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 44.23	R: 44.66	F1: 44.44
# 	Hypothesis #29 & Reference #1:
# 		metric:	P: 36.54	R: 37.25	F1: 36.89
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 35.58	R: 36.27	F1: 35.92
# 	Hypothesis #29 & Reference #3:
# 		metric:	P: 45.19	R: 46.53	F1: 45.85
# 	Hypothesis #30 & Reference #0:
# 		metric:	P: 29.41	R: 28.85	F1: 29.13
# 	Hypothesis #30 & Reference #1:
# 		metric:	P: 36.27	R: 35.92	F1: 36.10
# 	Hypothesis #30 & Reference #2:
# 		metric:	P: 31.37	R: 30.77	F1: 31.07
# 	Hypothesis #30 & Reference #3:
# 		metric:	P: 37.25	R: 34.55	F1: 35.85
# 	Hypothesis #31 & Reference #0:
# 		metric:	P: 30.10	R: 29.52	F1: 29.81
# 	Hypothesis #31 & Reference #1:
# 		metric:	P: 28.16	R: 28.16	F1: 28.16
# 	Hypothesis #31 & Reference #2:
# 		metric:	P: 25.24	R: 24.53	F1: 24.88
# 	Hypothesis #31 & Reference #3:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #32 & Reference #0:
# 		metric:	P: 29.70	R: 28.30	F1: 28.99
# 	Hypothesis #32 & Reference #1:
# 		metric:	P: 30.69	R: 29.81	F1: 30.24
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 39.60	R: 38.10	F1: 38.83
# 	Hypothesis #32 & Reference #3:
# 		metric:	P: 29.70	R: 29.70	F1: 29.70
# 	Hypothesis #33 & Reference #0:
# 		metric:	P: 26.17	R: 27.45	F1: 26.79
# 	Hypothesis #33 & Reference #1:
# 		metric:	P: 26.17	R: 28.28	F1: 27.18
# 	Hypothesis #33 & Reference #2:
# 		metric:	P: 18.69	R: 19.80	F1: 19.23
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 26.17	R: 26.67	F1: 26.42
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 35.29	R: 35.29	F1: 35.29
# 	Hypothesis #34 & Reference #1:
# 		metric:	P: 35.29	R: 36.36	F1: 35.82
# 	Hypothesis #34 & Reference #2:
# 		metric:	P: 32.35	R: 32.35	F1: 32.35
# 	Hypothesis #34 & Reference #3:
# 		metric:	P: 24.51	R: 24.75	F1: 24.63
# 	Hypothesis #35 & Reference #0:
# 		metric:	P: 33.94	R: 35.24	F1: 34.58
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 45.87	R: 46.30	F1: 46.08
# 	Hypothesis #35 & Reference #2:
# 		metric:	P: 38.53	R: 37.50	F1: 38.01
# 	Hypothesis #35 & Reference #3:
# 		metric:	P: 33.94	R: 35.92	F1: 34.91
# 	Hypothesis #36 & Reference #0:
# 		metric:	P: 25.00	R: 25.74	F1: 25.37
# 	Hypothesis #36 & Reference #1:
# 		metric:	P: 25.00	R: 25.74	F1: 25.37
# 	Hypothesis #36 & Reference #2:
# 		metric:	P: 22.12	R: 23.00	F1: 22.55
# 	Hypothesis #36 & Reference #3:
# 		metric:	P: 22.12	R: 22.55	F1: 22.33
# 	Hypothesis #37 & Reference #0:
# 		metric:	P: 42.16	R: 42.57	F1: 42.36
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 50.00	R: 50.50	F1: 50.25
# 	Hypothesis #37 & Reference #2:
# 		metric:	P: 31.37	R: 32.00	F1: 31.68
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 44.12	R: 44.55	F1: 44.33
# 	Hypothesis #38 & Reference #0:
# 		metric:	P: 27.45	R: 27.45	F1: 27.45
# 	Hypothesis #38 & Reference #1:
# 		metric:	P: 35.29	R: 34.95	F1: 35.12
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #38 & Reference #3:
# 		metric:	P: 31.37	R: 30.19	F1: 30.77
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 55.34	R: 57.00	F1: 56.16
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 44.66	R: 45.10	F1: 44.88
# 	Hypothesis #39 & Reference #2:
# 		metric:	P: 32.04	R: 33.00	F1: 32.51
# 	Hypothesis #39 & Reference #3:
# 		metric:	P: 26.21	R: 25.71	F1: 25.96
# 	Hypothesis #40 & Reference #0:
# 		metric:	P: 35.29	R: 34.29	F1: 34.78
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 38.24	R: 38.24	F1: 38.24
# 	Hypothesis #40 & Reference #2:
# 		metric:	P: 32.35	R: 31.13	F1: 31.73
# 	Hypothesis #40 & Reference #3:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #41 & Reference #0:
# 		metric:	P: 31.13	R: 31.73	F1: 31.43
# 	Hypothesis #41 & Reference #1:
# 		metric:	P: 32.08	R: 32.69	F1: 32.38
# 	Hypothesis #41 & Reference #2:
# 		metric:	P: 31.13	R: 31.73	F1: 31.43
# 	Hypothesis #41 & Reference #3:
# 		metric:	P: 21.70	R: 22.55	F1: 22.12
# 	Hypothesis #42 & Reference #0:
# 		metric:	P: 36.63	R: 35.92	F1: 36.27
# 	Hypothesis #42 & Reference #1:
# 		metric:	P: 36.63	R: 37.00	F1: 36.82
# 	Hypothesis #42 & Reference #2:
# 		metric:	P: 31.68	R: 31.07	F1: 31.37
# 	Hypothesis #42 & Reference #3:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #43 & Reference #0:
# 		metric:	P: 28.71	R: 29.00	F1: 28.86
# 	Hypothesis #43 & Reference #1:
# 		metric:	P: 31.68	R: 31.37	F1: 31.53
# 	Hypothesis #43 & Reference #2:
# 		metric:	P: 21.78	R: 21.78	F1: 21.78
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 26.73	R: 25.71	F1: 26.21
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 34.65	R: 34.65	F1: 34.65
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 32.67	R: 32.67	F1: 32.67
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #45 & Reference #0:
# 		metric:	P: 20.39	R: 20.59	F1: 20.49
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 27.18	R: 26.92	F1: 27.05
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 31.07	R: 31.68	F1: 31.37
# 	Hypothesis #45 & Reference #3:
# 		metric:	P: 19.42	R: 19.80	F1: 19.61
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 30.39	R: 30.69	F1: 30.54
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 30.39	R: 28.97	F1: 29.67
# 	Hypothesis #46 & Reference #2:
# 		metric:	P: 22.55	R: 22.12	F1: 22.33
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 31.37	R: 31.68	F1: 31.53
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 28.71	R: 29.00	F1: 28.86
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 30.69	R: 30.10	F1: 30.39
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 25.74	R: 25.74	F1: 25.74
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 29.70	R: 29.41	F1: 29.56
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 38.46	R: 38.46	F1: 38.46
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 39.42	R: 39.81	F1: 39.61
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 39.42	R: 39.81	F1: 39.61
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 33.65	R: 33.33	F1: 33.49
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 25.00	R: 24.53	F1: 24.76
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 26.92	R: 27.18	F1: 27.05
# 	Hypothesis #49 & Reference #2:
# 		metric:	P: 19.23	R: 19.61	F1: 19.42
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 25.96	R: 26.47	F1: 26.21
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 12.62	R: 12.62	F1: 12.62
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 11.65	R: 11.88	F1: 11.76
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 12.62	R: 13.13	F1: 12.87
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 13.59	R: 14.00	F1: 13.79
# 	Hypothesis #1 & Reference #0:
# 		metric:	P:  5.10	R:  4.72	F1:  4.90
# 	Hypothesis #1 & Reference #1:
# 		metric:	P:  4.08	R:  3.81	F1:  3.94
# 	Hypothesis #1 & Reference #2:
# 		metric:	P:  4.08	R:  3.92	F1:  4.00
# 	Hypothesis #1 & Reference #3:
# 		metric:	P:  8.16	R:  7.69	F1:  7.92
# 	Hypothesis #2 & Reference #0:
# 		metric:	P:  7.00	R:  6.93	F1:  6.97
# 	Hypothesis #2 & Reference #1:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 10.00	R:  9.90	F1:  9.95
# 	Hypothesis #2 & Reference #3:
# 		metric:	P:  6.00	R:  6.25	F1:  6.12
# 	Hypothesis #3 & Reference #0:
# 		metric:	P:  7.77	R:  7.69	F1:  7.73
# 	Hypothesis #3 & Reference #1:
# 		metric:	P:  4.85	R:  4.95	F1:  4.90
# 	Hypothesis #3 & Reference #2:
# 		metric:	P:  5.83	R:  5.94	F1:  5.88
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  1.94	R:  1.96	F1:  1.95
# 	Hypothesis #4 & Reference #0:
# 		metric:	P:  6.93	R:  7.07	F1:  7.00
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 10.89	R: 11.11	F1: 11.00
# 	Hypothesis #4 & Reference #2:
# 		metric:	P:  3.96	R:  3.96	F1:  3.96
# 	Hypothesis #4 & Reference #3:
# 		metric:	P:  5.94	R:  5.88	F1:  5.91
# 	Hypothesis #5 & Reference #0:
# 		metric:	P:  6.00	R:  5.94	F1:  5.97
# 	Hypothesis #5 & Reference #1:
# 		metric:	P:  1.00	R:  1.02	F1:  1.01
# 	Hypothesis #5 & Reference #2:
# 		metric:	P:  6.00	R:  6.00	F1:  6.00
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #6 & Reference #0:
# 		metric:	P:  6.48	R:  6.80	F1:  6.64
# 	Hypothesis #6 & Reference #1:
# 		metric:	P:  4.63	R:  5.00	F1:  4.81
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 12.04	R: 13.00	F1: 12.50
# 	Hypothesis #6 & Reference #3:
# 		metric:	P:  2.78	R:  2.91	F1:  2.84
# 	Hypothesis #7 & Reference #0:
# 		metric:	P:  5.83	R:  6.19	F1:  6.00
# 	Hypothesis #7 & Reference #1:
# 		metric:	P:  7.77	R:  8.16	F1:  7.96
# 	Hypothesis #7 & Reference #2:
# 		metric:	P:  6.80	R:  7.07	F1:  6.93
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 10.68	R: 11.22	F1: 10.95
# 	Hypothesis #8 & Reference #0:
# 		metric:	P:  4.95	R:  5.10	F1:  5.03
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #8 & Reference #2:
# 		metric:	P:  6.93	R:  6.93	F1:  6.93
# 	Hypothesis #8 & Reference #3:
# 		metric:	P:  6.93	R:  6.86	F1:  6.90
# 	Hypothesis #9 & Reference #0:
# 		metric:	P:  3.03	R:  2.94	F1:  2.99
# 	Hypothesis #9 & Reference #1:
# 		metric:	P:  6.06	R:  6.06	F1:  6.06
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 14.14	R: 13.46	F1: 13.79
# 	Hypothesis #9 & Reference #3:
# 		metric:	P:  6.06	R:  5.88	F1:  5.97
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 14.42	R: 14.71	F1: 14.56
# 	Hypothesis #10 & Reference #1:
# 		metric:	P:  1.92	R:  1.98	F1:  1.95
# 	Hypothesis #10 & Reference #2:
# 		metric:	P:  2.88	R:  2.94	F1:  2.91
# 	Hypothesis #10 & Reference #3:
# 		metric:	P:  3.85	R:  4.04	F1:  3.94
# 	Hypothesis #11 & Reference #0:
# 		metric:	P:  7.92	R:  7.84	F1:  7.88
# 	Hypothesis #11 & Reference #1:
# 		metric:	P:  2.97	R:  3.03	F1:  3.00
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  2.97	R:  2.91	F1:  2.94
# 	Hypothesis #11 & Reference #3:
# 		metric:	P:  3.96	R:  3.88	F1:  3.92
# 	Hypothesis #12 & Reference #0:
# 		metric:	P:  3.88	R:  4.00	F1:  3.94
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 17.48	R: 17.82	F1: 17.65
# 	Hypothesis #12 & Reference #2:
# 		metric:	P:  5.83	R:  6.00	F1:  5.91
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  1.94	R:  1.96	F1:  1.95
# 	Hypothesis #13 & Reference #0:
# 		metric:	P:  7.00	R:  6.93	F1:  6.97
# 	Hypothesis #13 & Reference #1:
# 		metric:	P:  4.00	R:  3.96	F1:  3.98
# 	Hypothesis #13 & Reference #2:
# 		metric:	P:  5.00	R:  5.26	F1:  5.13
# 	Hypothesis #13 & Reference #3:
# 		metric:	P:  2.00	R:  1.94	F1:  1.97
# 	Hypothesis #14 & Reference #0:
# 		metric:	P:  3.81	R:  4.04	F1:  3.92
# 	Hypothesis #14 & Reference #1:
# 		metric:	P:  2.86	R:  3.19	F1:  3.02
# 	Hypothesis #14 & Reference #2:
# 		metric:	P:  7.62	R:  7.92	F1:  7.77
# 	Hypothesis #14 & Reference #3:
# 		metric:	P:  2.86	R:  2.97	F1:  2.91
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  0.92	R:  1.05	F1:  0.98
# 	Hypothesis #15 & Reference #1:
# 		metric:	P:  1.83	R:  2.02	F1:  1.92
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  0.92	R:  0.99	F1:  0.95
# 	Hypothesis #16 & Reference #0:
# 		metric:	P:  4.76	R:  4.90	F1:  4.83
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 10.48	R: 11.00	F1: 10.73
# 	Hypothesis #16 & Reference #2:
# 		metric:	P:  8.57	R:  8.74	F1:  8.65
# 	Hypothesis #16 & Reference #3:
# 		metric:	P:  4.76	R:  4.95	F1:  4.85
# 	Hypothesis #17 & Reference #0:
# 		metric:	P:  6.86	R:  6.73	F1:  6.80
# 	Hypothesis #17 & Reference #1:
# 		metric:	P:  6.86	R:  6.86	F1:  6.86
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  1.96	R:  1.92	F1:  1.94
# 	Hypothesis #17 & Reference #3:
# 		metric:	P:  3.92	R:  3.77	F1:  3.85
# 	Hypothesis #18 & Reference #0:
# 		metric:	P:  6.86	R:  6.73	F1:  6.80
# 	Hypothesis #18 & Reference #1:
# 		metric:	P:  5.88	R:  6.06	F1:  5.97
# 	Hypothesis #18 & Reference #2:
# 		metric:	P:  6.86	R:  6.67	F1:  6.76
# 	Hypothesis #18 & Reference #3:
# 		metric:	P:  1.96	R:  1.94	F1:  1.95
# 	Hypothesis #19 & Reference #0:
# 		metric:	P:  3.92	R:  3.96	F1:  3.94
# 	Hypothesis #19 & Reference #1:
# 		metric:	P:  7.84	R:  8.00	F1:  7.92
# 	Hypothesis #19 & Reference #2:
# 		metric:	P:  4.90	R:  4.90	F1:  4.90
# 	Hypothesis #19 & Reference #3:
# 		metric:	P:  5.88	R:  5.83	F1:  5.85
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 10.78	R: 11.70	F1: 11.22
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 11.76	R: 12.00	F1: 11.88
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  1.96	R:  1.98	F1:  1.97
# 	Hypothesis #20 & Reference #3:
# 		metric:	P:  5.88	R:  6.06	F1:  5.97
# 	Hypothesis #21 & Reference #0:
# 		metric:	P:  3.00	R:  3.03	F1:  3.02
# 	Hypothesis #21 & Reference #1:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #21 & Reference #2:
# 		metric:	P:  2.00	R:  1.92	F1:  1.96
# 	Hypothesis #21 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 10.58	R: 10.78	F1: 10.68
# 	Hypothesis #22 & Reference #1:
# 		metric:	P:  4.81	R:  4.95	F1:  4.88
# 	Hypothesis #22 & Reference #2:
# 		metric:	P:  6.73	R:  6.86	F1:  6.80
# 	Hypothesis #22 & Reference #3:
# 		metric:	P:  6.73	R:  7.07	F1:  6.90
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 19.19	R: 18.63	F1: 18.91
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 10.10	R: 10.10	F1: 10.10
# 	Hypothesis #23 & Reference #2:
# 		metric:	P:  9.09	R:  8.57	F1:  8.82
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 17.17	R: 16.83	F1: 17.00
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 10.10	R: 10.10	F1: 10.10
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 13.13	R: 13.13	F1: 13.13
# 	Hypothesis #24 & Reference #2:
# 		metric:	P:  7.07	R:  7.00	F1:  7.04
# 	Hypothesis #24 & Reference #3:
# 		metric:	P:  4.04	R:  3.88	F1:  3.96
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #25 & Reference #1:
# 		metric:	P:  3.00	R:  3.03	F1:  3.02
# 	Hypothesis #25 & Reference #2:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #25 & Reference #3:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #26 & Reference #0:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 13.73	R: 14.89	F1: 14.29
# 	Hypothesis #26 & Reference #2:
# 		metric:	P:  7.84	R:  7.92	F1:  7.88
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 10.78	R: 11.11	F1: 10.95
# 	Hypothesis #27 & Reference #0:
# 		metric:	P:  7.84	R:  7.84	F1:  7.84
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 10.78	R: 10.68	F1: 10.73
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 14.71	R: 14.71	F1: 14.71
# 	Hypothesis #27 & Reference #3:
# 		metric:	P:  6.86	R:  6.86	F1:  6.86
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 14.00	R: 13.73	F1: 13.86
# 	Hypothesis #28 & Reference #1:
# 		metric:	P:  5.00	R:  5.26	F1:  5.13
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 11.00	R: 11.00	F1: 11.00
# 	Hypothesis #28 & Reference #3:
# 		metric:	P:  6.00	R:  5.77	F1:  5.88
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 14.56	R: 14.71	F1: 14.63
# 	Hypothesis #29 & Reference #1:
# 		metric:	P:  8.74	R:  8.91	F1:  8.82
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 14.56	R: 14.85	F1: 14.71
# 	Hypothesis #29 & Reference #3:
# 		metric:	P:  9.71	R: 10.00	F1:  9.85
# 	Hypothesis #30 & Reference #0:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #30 & Reference #1:
# 		metric:	P:  4.95	R:  4.90	F1:  4.93
# 	Hypothesis #30 & Reference #2:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #30 & Reference #3:
# 		metric:	P:  6.93	R:  6.42	F1:  6.67
# 	Hypothesis #31 & Reference #0:
# 		metric:	P:  5.88	R:  5.77	F1:  5.83
# 	Hypothesis #31 & Reference #1:
# 		metric:	P:  3.92	R:  3.92	F1:  3.92
# 	Hypothesis #31 & Reference #2:
# 		metric:	P:  2.94	R:  2.86	F1:  2.90
# 	Hypothesis #31 & Reference #3:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #32 & Reference #0:
# 		metric:	P:  3.00	R:  2.86	F1:  2.93
# 	Hypothesis #32 & Reference #1:
# 		metric:	P:  3.00	R:  2.91	F1:  2.96
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 14.00	R: 13.46	F1: 13.73
# 	Hypothesis #32 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #33 & Reference #0:
# 		metric:	P:  3.77	R:  3.96	F1:  3.86
# 	Hypothesis #33 & Reference #1:
# 		metric:	P:  6.60	R:  7.14	F1:  6.86
# 	Hypothesis #33 & Reference #2:
# 		metric:	P:  4.72	R:  5.00	F1:  4.85
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 10.38	R: 10.58	F1: 10.48
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 10.89	R: 10.89	F1: 10.89
# 	Hypothesis #34 & Reference #1:
# 		metric:	P:  5.94	R:  6.12	F1:  6.03
# 	Hypothesis #34 & Reference #2:
# 		metric:	P:  2.97	R:  2.97	F1:  2.97
# 	Hypothesis #34 & Reference #3:
# 		metric:	P:  0.99	R:  1.00	F1:  1.00
# 	Hypothesis #35 & Reference #0:
# 		metric:	P:  6.48	R:  6.73	F1:  6.60
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 12.04	R: 12.15	F1: 12.09
# 	Hypothesis #35 & Reference #2:
# 		metric:	P:  8.33	R:  8.11	F1:  8.22
# 	Hypothesis #35 & Reference #3:
# 		metric:	P:  3.70	R:  3.92	F1:  3.81
# 	Hypothesis #36 & Reference #0:
# 		metric:	P:  2.91	R:  3.00	F1:  2.96
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  3.88	R:  4.00	F1:  3.94
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  0.97	R:  1.01	F1:  0.99
# 	Hypothesis #36 & Reference #3:
# 		metric:	P:  3.88	R:  3.96	F1:  3.92
# 	Hypothesis #37 & Reference #0:
# 		metric:	P:  8.91	R:  9.00	F1:  8.96
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 17.82	R: 18.00	F1: 17.91
# 	Hypothesis #37 & Reference #2:
# 		metric:	P:  7.92	R:  8.08	F1:  8.00
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 20.79	R: 21.00	F1: 20.90
# 	Hypothesis #38 & Reference #0:
# 		metric:	P:  7.92	R:  7.92	F1:  7.92
# 	Hypothesis #38 & Reference #1:
# 		metric:	P:  7.92	R:  7.84	F1:  7.88
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 10.89	R: 10.78	F1: 10.84
# 	Hypothesis #38 & Reference #3:
# 		metric:	P:  6.93	R:  6.67	F1:  6.80
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 26.47	R: 27.27	F1: 26.87
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 12.75	R: 12.87	F1: 12.81
# 	Hypothesis #39 & Reference #2:
# 		metric:	P:  4.90	R:  5.05	F1:  4.98
# 	Hypothesis #39 & Reference #3:
# 		metric:	P:  5.88	R:  5.77	F1:  5.83
# 	Hypothesis #40 & Reference #0:
# 		metric:	P:  5.94	R:  5.77	F1:  5.85
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 14.85	R: 14.85	F1: 14.85
# 	Hypothesis #40 & Reference #2:
# 		metric:	P:  4.95	R:  4.76	F1:  4.85
# 	Hypothesis #40 & Reference #3:
# 		metric:	P:  1.98	R:  1.96	F1:  1.97
# 	Hypothesis #41 & Reference #0:
# 		metric:	P:  3.81	R:  3.88	F1:  3.85
# 	Hypothesis #41 & Reference #1:
# 		metric:	P:  2.86	R:  2.91	F1:  2.88
# 	Hypothesis #41 & Reference #2:
# 		metric:	P:  2.86	R:  2.91	F1:  2.88
# 	Hypothesis #41 & Reference #3:
# 		metric:	P:  4.76	R:  4.95	F1:  4.85
# 	Hypothesis #42 & Reference #0:
# 		metric:	P:  9.00	R:  8.82	F1:  8.91
# 	Hypothesis #42 & Reference #1:
# 		metric:	P:  7.00	R:  7.07	F1:  7.04
# 	Hypothesis #42 & Reference #2:
# 		metric:	P:  5.00	R:  4.90	F1:  4.95
# 	Hypothesis #42 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #43 & Reference #0:
# 		metric:	P:  7.00	R:  7.07	F1:  7.04
# 	Hypothesis #43 & Reference #1:
# 		metric:	P:  6.00	R:  5.94	F1:  5.97
# 	Hypothesis #43 & Reference #2:
# 		metric:	P:  2.00	R:  2.00	F1:  2.00
# 	Hypothesis #43 & Reference #3:
# 		metric:	P:  7.00	R:  6.73	F1:  6.86
# 	Hypothesis #44 & Reference #0:
# 		metric:	P:  5.00	R:  5.00	F1:  5.00
# 	Hypothesis #44 & Reference #1:
# 		metric:	P:  8.00	R:  8.00	F1:  8.00
# 	Hypothesis #44 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #44 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  2.94	R:  2.97	F1:  2.96
# 	Hypothesis #45 & Reference #1:
# 		metric:	P:  5.88	R:  5.83	F1:  5.85
# 	Hypothesis #45 & Reference #2:
# 		metric:	P:  8.82	R:  9.00	F1:  8.91
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  1.96	R:  2.00	F1:  1.98
# 	Hypothesis #46 & Reference #0:
# 		metric:	P:  3.96	R:  4.00	F1:  3.98
# 	Hypothesis #46 & Reference #1:
# 		metric:	P:  3.96	R:  3.77	F1:  3.86
# 	Hypothesis #46 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #46 & Reference #3:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #47 & Reference #0:
# 		metric:	P:  4.00	R:  4.04	F1:  4.02
# 	Hypothesis #47 & Reference #1:
# 		metric:	P:  4.00	R:  3.92	F1:  3.96
# 	Hypothesis #47 & Reference #2:
# 		metric:	P:  2.00	R:  2.00	F1:  2.00
# 	Hypothesis #47 & Reference #3:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #48 & Reference #0:
# 		metric:	P:  8.74	R:  8.74	F1:  8.74
# 	Hypothesis #48 & Reference #1:
# 		metric:	P:  9.71	R:  9.80	F1:  9.76
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 11.65	R: 11.76	F1: 11.71
# 	Hypothesis #48 & Reference #3:
# 		metric:	P:  4.85	R:  4.81	F1:  4.83
# 	Hypothesis #49 & Reference #0:
# 		metric:	P:  3.88	R:  3.81	F1:  3.85
# 	Hypothesis #49 & Reference #1:
# 		metric:	P:  6.80	R:  6.86	F1:  6.83
# 	Hypothesis #49 & Reference #2:
# 		metric:	P:  0.97	R:  0.99	F1:  0.98
# 	Hypothesis #49 & Reference #3:
# 		metric:	P:  3.88	R:  3.96	F1:  3.92
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P:  4.90	R:  4.90	F1:  4.90
# 	Hypothesis #0 & Reference #1:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #0 & Reference #2:
# 		metric:	P:  4.90	R:  5.10	F1:  5.00
# 	Hypothesis #0 & Reference #3:
# 		metric:	P:  3.92	R:  4.04	F1:  3.98
# 	Hypothesis #1 & Reference #0:
# 		metric:	P:  1.03	R:  0.95	F1:  0.99
# 	Hypothesis #1 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #1 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #1 & Reference #3:
# 		metric:	P:  3.09	R:  2.91	F1:  3.00
# 	Hypothesis #2 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #2 & Reference #1:
# 		metric:	P:  2.02	R:  2.00	F1:  2.01
# 	Hypothesis #2 & Reference #2:
# 		metric:	P:  4.04	R:  4.00	F1:  4.02
# 	Hypothesis #2 & Reference #3:
# 		metric:	P:  1.01	R:  1.05	F1:  1.03
# 	Hypothesis #3 & Reference #0:
# 		metric:	P:  0.98	R:  0.97	F1:  0.98
# 	Hypothesis #3 & Reference #1:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #3 & Reference #2:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #4 & Reference #0:
# 		metric:	P:  1.00	R:  1.02	F1:  1.01
# 	Hypothesis #4 & Reference #1:
# 		metric:	P:  5.00	R:  5.10	F1:  5.05
# 	Hypothesis #4 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #4 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #5 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #5 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #5 & Reference #2:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #6 & Reference #0:
# 		metric:	P:  2.80	R:  2.94	F1:  2.87
# 	Hypothesis #6 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #6 & Reference #2:
# 		metric:	P:  3.74	R:  4.04	F1:  3.88
# 	Hypothesis #6 & Reference #3:
# 		metric:	P:  0.93	R:  0.98	F1:  0.96
# 	Hypothesis #7 & Reference #0:
# 		metric:	P:  0.98	R:  1.04	F1:  1.01
# 	Hypothesis #7 & Reference #1:
# 		metric:	P:  3.92	R:  4.12	F1:  4.02
# 	Hypothesis #7 & Reference #2:
# 		metric:	P:  1.96	R:  2.04	F1:  2.00
# 	Hypothesis #7 & Reference #3:
# 		metric:	P:  2.94	R:  3.09	F1:  3.02
# 	Hypothesis #8 & Reference #0:
# 		metric:	P:  2.00	R:  2.06	F1:  2.03
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #8 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #8 & Reference #3:
# 		metric:	P:  2.00	R:  1.98	F1:  1.99
# 	Hypothesis #9 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #9 & Reference #1:
# 		metric:	P:  1.02	R:  1.02	F1:  1.02
# 	Hypothesis #9 & Reference #2:
# 		metric:	P:  8.16	R:  7.77	F1:  7.96
# 	Hypothesis #9 & Reference #3:
# 		metric:	P:  2.04	R:  1.98	F1:  2.01
# 	Hypothesis #10 & Reference #0:
# 		metric:	P:  8.74	R:  8.91	F1:  8.82
# 	Hypothesis #10 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #10 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #10 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #0:
# 		metric:	P:  2.00	R:  1.98	F1:  1.99
# 	Hypothesis #11 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #12 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 12.75	R: 13.00	F1: 12.87
# 	Hypothesis #12 & Reference #2:
# 		metric:	P:  2.94	R:  3.03	F1:  2.99
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #13 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #13 & Reference #1:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #13 & Reference #2:
# 		metric:	P:  1.01	R:  1.06	F1:  1.04
# 	Hypothesis #13 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #14 & Reference #0:
# 		metric:	P:  0.96	R:  1.02	F1:  0.99
# 	Hypothesis #14 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #14 & Reference #2:
# 		metric:	P:  1.92	R:  2.00	F1:  1.96
# 	Hypothesis #14 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #16 & Reference #0:
# 		metric:	P:  1.92	R:  1.98	F1:  1.95
# 	Hypothesis #16 & Reference #1:
# 		metric:	P:  5.77	R:  6.06	F1:  5.91
# 	Hypothesis #16 & Reference #2:
# 		metric:	P:  2.88	R:  2.94	F1:  2.91
# 	Hypothesis #16 & Reference #3:
# 		metric:	P:  0.96	R:  1.00	F1:  0.98
# 	Hypothesis #17 & Reference #0:
# 		metric:	P:  3.96	R:  3.88	F1:  3.92
# 	Hypothesis #17 & Reference #1:
# 		metric:	P:  3.96	R:  3.96	F1:  3.96
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #17 & Reference #3:
# 		metric:	P:  0.99	R:  0.95	F1:  0.97
# 	Hypothesis #18 & Reference #0:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #18 & Reference #1:
# 		metric:	P:  0.99	R:  1.02	F1:  1.01
# 	Hypothesis #18 & Reference #2:
# 		metric:	P:  0.99	R:  0.96	F1:  0.98
# 	Hypothesis #18 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #1:
# 		metric:	P:  1.98	R:  2.02	F1:  2.00
# 	Hypothesis #19 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #3:
# 		metric:	P:  0.99	R:  0.98	F1:  0.99
# 	Hypothesis #20 & Reference #0:
# 		metric:	P:  2.97	R:  3.23	F1:  3.09
# 	Hypothesis #20 & Reference #1:
# 		metric:	P:  4.95	R:  5.05	F1:  5.00
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #20 & Reference #3:
# 		metric:	P:  2.97	R:  3.06	F1:  3.02
# 	Hypothesis #21 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #21 & Reference #1:
# 		metric:	P:  2.02	R:  2.00	F1:  2.01
# 	Hypothesis #21 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #21 & Reference #3:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #22 & Reference #0:
# 		metric:	P:  1.94	R:  1.98	F1:  1.96
# 	Hypothesis #22 & Reference #1:
# 		metric:	P:  0.97	R:  1.00	F1:  0.99
# 	Hypothesis #22 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #22 & Reference #3:
# 		metric:	P:  1.94	R:  2.04	F1:  1.99
# 	Hypothesis #23 & Reference #0:
# 		metric:	P:  9.18	R:  8.91	F1:  9.05
# 	Hypothesis #23 & Reference #1:
# 		metric:	P:  6.12	R:  6.12	F1:  6.12
# 	Hypothesis #23 & Reference #2:
# 		metric:	P:  4.08	R:  3.85	F1:  3.96
# 	Hypothesis #23 & Reference #3:
# 		metric:	P:  7.14	R:  7.00	F1:  7.07
# 	Hypothesis #24 & Reference #0:
# 		metric:	P:  1.02	R:  1.02	F1:  1.02
# 	Hypothesis #24 & Reference #1:
# 		metric:	P:  9.18	R:  9.18	F1:  9.18
# 	Hypothesis #24 & Reference #2:
# 		metric:	P:  1.02	R:  1.01	F1:  1.02
# 	Hypothesis #24 & Reference #3:
# 		metric:	P:  1.02	R:  0.98	F1:  1.00
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #25 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #25 & Reference #2:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #25 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #26 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #26 & Reference #1:
# 		metric:	P:  7.92	R:  8.60	F1:  8.25
# 	Hypothesis #26 & Reference #2:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #26 & Reference #3:
# 		metric:	P:  3.96	R:  4.08	F1:  4.02
# 	Hypothesis #27 & Reference #0:
# 		metric:	P:  1.98	R:  1.98	F1:  1.98
# 	Hypothesis #27 & Reference #1:
# 		metric:	P:  6.93	R:  6.86	F1:  6.90
# 	Hypothesis #27 & Reference #2:
# 		metric:	P:  7.92	R:  7.92	F1:  7.92
# 	Hypothesis #27 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 10.10	R:  9.90	F1: 10.00
# 	Hypothesis #28 & Reference #1:
# 		metric:	P:  1.01	R:  1.06	F1:  1.04
# 	Hypothesis #28 & Reference #2:
# 		metric:	P:  4.04	R:  4.04	F1:  4.04
# 	Hypothesis #28 & Reference #3:
# 		metric:	P:  1.01	R:  0.97	F1:  0.99
# 	Hypothesis #29 & Reference #0:
# 		metric:	P:  5.88	R:  5.94	F1:  5.91
# 	Hypothesis #29 & Reference #1:
# 		metric:	P:  1.96	R:  2.00	F1:  1.98
# 	Hypothesis #29 & Reference #2:
# 		metric:	P:  6.86	R:  7.00	F1:  6.93
# 	Hypothesis #29 & Reference #3:
# 		metric:	P:  1.96	R:  2.02	F1:  1.99
# 	Hypothesis #30 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #3:
# 		metric:	P:  1.00	R:  0.93	F1:  0.96
# 	Hypothesis #31 & Reference #0:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #31 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #31 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #31 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #2:
# 		metric:	P:  8.08	R:  7.77	F1:  7.92
# 	Hypothesis #32 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #33 & Reference #0:
# 		metric:	P:  0.95	R:  1.00	F1:  0.98
# 	Hypothesis #33 & Reference #1:
# 		metric:	P:  1.90	R:  2.06	F1:  1.98
# 	Hypothesis #33 & Reference #2:
# 		metric:	P:  1.90	R:  2.02	F1:  1.96
# 	Hypothesis #33 & Reference #3:
# 		metric:	P:  6.67	R:  6.80	F1:  6.73
# 	Hypothesis #34 & Reference #0:
# 		metric:	P:  4.00	R:  4.00	F1:  4.00
# 	Hypothesis #34 & Reference #1:
# 		metric:	P:  1.00	R:  1.03	F1:  1.02
# 	Hypothesis #34 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #34 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #35 & Reference #0:
# 		metric:	P:  1.87	R:  1.94	F1:  1.90
# 	Hypothesis #35 & Reference #1:
# 		metric:	P:  5.61	R:  5.66	F1:  5.63
# 	Hypothesis #35 & Reference #2:
# 		metric:	P:  2.80	R:  2.73	F1:  2.76
# 	Hypothesis #35 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  0.98	R:  1.01	F1:  1.00
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #37 & Reference #0:
# 		metric:	P:  4.00	R:  4.04	F1:  4.02
# 	Hypothesis #37 & Reference #1:
# 		metric:	P:  8.00	R:  8.08	F1:  8.04
# 	Hypothesis #37 & Reference #2:
# 		metric:	P:  2.00	R:  2.04	F1:  2.02
# 	Hypothesis #37 & Reference #3:
# 		metric:	P:  8.00	R:  8.08	F1:  8.04
# 	Hypothesis #38 & Reference #0:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #38 & Reference #1:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #38 & Reference #2:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #38 & Reference #3:
# 		metric:	P:  2.00	R:  1.92	F1:  1.96
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 12.87	R: 13.27	F1: 13.07
# 	Hypothesis #39 & Reference #1:
# 		metric:	P:  6.93	R:  7.00	F1:  6.97
# 	Hypothesis #39 & Reference #2:
# 		metric:	P:  0.99	R:  1.02	F1:  1.01
# 	Hypothesis #39 & Reference #3:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #40 & Reference #0:
# 		metric:	P:  1.00	R:  0.97	F1:  0.99
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 12.00	R: 12.00	F1: 12.00
# 	Hypothesis #40 & Reference #2:
# 		metric:	P:  1.00	R:  0.96	F1:  0.98
# 	Hypothesis #40 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #2:
# 		metric:	P:  0.96	R:  0.98	F1:  0.97
# 	Hypothesis #41 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #42 & Reference #0:
# 		metric:	P:  3.03	R:  2.97	F1:  3.00
# 	Hypothesis #42 & Reference #1:
# 		metric:	P:  1.01	R:  1.02	F1:  1.02
# 	Hypothesis #42 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #42 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #43 & Reference #0:
# 		metric:	P:  3.03	R:  3.06	F1:  3.05
# 	Hypothesis #43 & Reference #1:
# 		metric:	P:  3.03	R:  3.00	F1:  3.02
# 	Hypothesis #43 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #43 & Reference #3:
# 		metric:	P:  1.01	R:  0.97	F1:  0.99
# 	Hypothesis #44 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #44 & Reference #1:
# 		metric:	P:  2.02	R:  2.02	F1:  2.02
# 	Hypothesis #44 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #44 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #45 & Reference #1:
# 		metric:	P:  2.97	R:  2.94	F1:  2.96
# 	Hypothesis #45 & Reference #2:
# 		metric:	P:  4.95	R:  5.05	F1:  5.00
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #46 & Reference #0:
# ...
# 		metric:	P: 23.76	R: 23.76	F1: 23.76
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 24.85	R: 24.06	F1: 24.45
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 29.14	R: 29.14	F1: 29.14
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 27.01	R: 27.01	F1: 27.01
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 29.14	R: 29.14	F1: 29.14
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 27.01	R: 27.01	F1: 27.01
# 	Hypothesis #45 & Reference #0:
# 		metric:	P: 18.96	R: 19.11	F1: 19.03
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 23.37	R: 23.18	F1: 23.28
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 30.73	R: 31.24	F1: 30.98
# 	Hypothesis #45 & Reference #3:
# 		metric:	P: 17.82	R: 18.11	F1: 17.97
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 25.73	R: 25.94	F1: 25.83
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 25.73	R: 24.72	F1: 25.21
# 	Hypothesis #46 & Reference #2:
# 		metric:	P: 20.24	R: 19.92	F1: 20.08
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 28.90	R: 29.14	F1: 29.02
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 23.76	R: 23.95	F1: 23.86
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 28.08	R: 27.63	F1: 27.85
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 23.76	R: 23.76	F1: 23.76
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 24.85	R: 24.65	F1: 24.75
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 31.50	R: 31.50	F1: 31.50
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 33.50	R: 33.78	F1: 33.64
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 31.50	R: 31.75	F1: 31.62
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 27.40	R: 27.19	F1: 27.30
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 24.25	R: 23.87	F1: 24.06
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 24.25	R: 24.45	F1: 24.35
# 	Hypothesis #49 & Reference #2:
# 		metric:	P: 18.80	R: 19.11	F1: 18.96
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 24.25	R: 24.65	F1: 24.45
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 17.80	R:  7.03	F1: 10.08
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 15.95	R:  6.45	F1:  9.18
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 18.35	R:  7.60	F1: 10.75
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 17.07	R:  6.98	F1:  9.91
# 	Hypothesis #1 & Reference #0:
# 		metric:	P: 12.30	R:  4.47	F1:  6.56
# 	Hypothesis #1 & Reference #1:
# 		metric:	P: 11.56	R:  4.25	F1:  6.21
# 	Hypothesis #1 & Reference #2:
# 		metric:	P: 11.91	R:  4.53	F1:  6.56
# 	Hypothesis #1 & Reference #3:
# 		metric:	P: 14.18	R:  5.27	F1:  7.68
# 	Hypothesis #2 & Reference #0:
# 		metric:	P: 13.40	R:  5.26	F1:  7.55
# 	Hypothesis #2 & Reference #1:
# 		metric:	P: 13.62	R:  5.35	F1:  7.68
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 16.36	R:  6.42	F1:  9.22
# 	Hypothesis #2 & Reference #3:
# 		metric:	P: 13.83	R:  5.77	F1:  8.14
# 	Hypothesis #3 & Reference #0:
# 		metric:	P: 12.67	R:  4.95	F1:  7.12
# 	Hypothesis #3 & Reference #1:
# 		metric:	P: 11.48	R:  4.64	F1:  6.61
# 	Hypothesis #3 & Reference #2:
# 		metric:	P: 11.42	R:  4.62	F1:  6.58
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  9.49	R:  3.79	F1:  5.42
# 	Hypothesis #4 & Reference #0:
# 		metric:	P: 10.14	R:  4.12	F1:  5.85
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 18.01	R:  7.31	F1: 10.40
# 	Hypothesis #4 & Reference #2:
# 		metric:	P: 11.49	R:  4.56	F1:  6.52
# 	Hypothesis #4 & Reference #3:
# 		metric:	P: 11.72	R:  4.59	F1:  6.60
# 	Hypothesis #5 & Reference #0:
# 		metric:	P: 15.38	R:  6.04	F1:  8.67
# 	Hypothesis #5 & Reference #1:
# 		metric:	P: 10.60	R:  4.31	F1:  6.13
# 	Hypothesis #5 & Reference #2:
# 		metric:	P: 13.47	R:  5.35	F1:  7.66
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  9.40	R:  3.69	F1:  5.30
# 	Hypothesis #6 & Reference #0:
# 		metric:	P: 13.07	R:  5.41	F1:  7.65
# 	Hypothesis #6 & Reference #1:
# 		metric:	P: 12.34	R:  5.29	F1:  7.41
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 19.18	R:  8.23	F1: 11.51
# 	Hypothesis #6 & Reference #3:
# 		metric:	P: 12.93	R:  5.35	F1:  7.57
# 	Hypothesis #7 & Reference #0:
# 		metric:	P: 12.66	R:  5.37	F1:  7.54
# 	Hypothesis #7 & Reference #1:
# 		metric:	P: 15.26	R:  6.40	F1:  9.01
# 	Hypothesis #7 & Reference #2:
# 		metric:	P: 12.88	R:  5.33	F1:  7.54
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 12.04	R:  5.04	F1:  7.11
# 	Hypothesis #8 & Reference #0:
# 		metric:	P: 12.99	R:  5.34	F1:  7.57
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  9.15	R:  3.55	F1:  5.11
# 	Hypothesis #8 & Reference #2:
# 		metric:	P: 12.21	R:  4.84	F1:  6.93
# 	Hypothesis #8 & Reference #3:
# 		metric:	P: 14.08	R:  5.52	F1:  7.93
# 	Hypothesis #9 & Reference #0:
# 		metric:	P: 11.21	R:  4.31	F1:  6.22
# 	Hypothesis #9 & Reference #1:
# 		metric:	P: 11.59	R:  4.62	F1:  6.60
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 18.18	R:  6.83	F1:  9.92
# 	Hypothesis #9 & Reference #3:
# 		metric:	P: 12.91	R:  4.96	F1:  7.17
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 17.12	R:  6.91	F1:  9.84
# 	Hypothesis #10 & Reference #1:
# 		metric:	P: 11.51	R:  4.70	F1:  6.67
# 	Hypothesis #10 & Reference #2:
# 		metric:	P: 11.59	R:  4.68	F1:  6.67
# 	Hypothesis #10 & Reference #3:
# 		metric:	P: 12.88	R:  5.38	F1:  7.59
# 	Hypothesis #11 & Reference #0:
# 		metric:	P: 14.18	R:  5.56	F1:  7.98
# 	Hypothesis #11 & Reference #1:
# 		metric:	P: 15.25	R:  6.19	F1:  8.81
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  9.38	R:  3.63	F1:  5.24
# 	Hypothesis #11 & Reference #3:
# 		metric:	P: 12.07	R:  4.67	F1:  6.74
# 	Hypothesis #12 & Reference #0:
# 		metric:	P: 13.48	R:  5.51	F1:  7.83
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 19.45	R:  7.87	F1: 11.20
# 	Hypothesis #12 & Reference #2:
# 		metric:	P: 11.34	R:  4.64	F1:  6.58
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  8.32	R:  3.33	F1:  4.75
# 	Hypothesis #13 & Reference #0:
# 		metric:	P: 14.92	R:  5.86	F1:  8.41
# 	Hypothesis #13 & Reference #1:
# 		metric:	P: 14.36	R:  5.64	F1:  8.10
# 	Hypothesis #13 & Reference #2:
# 		metric:	P: 10.51	R:  4.44	F1:  6.24
# 	Hypothesis #13 & Reference #3:
# 		metric:	P: 12.32	R:  4.72	F1:  6.83
# 	Hypothesis #14 & Reference #0:
# 		metric:	P: 11.47	R:  4.84	F1:  6.81
# 	Hypothesis #14 & Reference #1:
# 		metric:	P: 11.61	R:  5.21	F1:  7.19
# 	Hypothesis #14 & Reference #2:
# 		metric:	P: 13.96	R:  5.75	F1:  8.15
# 	Hypothesis #14 & Reference #3:
# 		metric:	P: 10.79	R:  4.45	F1:  6.30
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  8.34	R:  3.84	F1:  5.26
# 	Hypothesis #15 & Reference #1:
# 		metric:	P: 10.38	R:  4.54	F1:  6.32
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  6.19	R:  2.75	F1:  3.80
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  8.49	R:  3.63	F1:  5.08
# 	Hypothesis #16 & Reference #0:
# 		metric:	P: 11.55	R:  4.70	F1:  6.68
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 17.02	R:  7.10	F1: 10.02
# 	Hypothesis #16 & Reference #2:
# 		metric:	P: 14.01	R:  5.64	F1:  8.04
# 	Hypothesis #16 & Reference #3:
# 		metric:	P: 11.82	R:  4.87	F1:  6.90
# 	Hypothesis #17 & Reference #0:
# 		metric:	P: 12.24	R:  4.73	F1:  6.83
# 	Hypothesis #17 & Reference #1:
# 		metric:	P: 11.99	R:  4.75	F1:  6.80
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  9.65	R:  3.73	F1:  5.38
# 	Hypothesis #17 & Reference #3:
# 		metric:	P: 11.73	R:  4.43	F1:  6.44
# 	Hypothesis #18 & Reference #0:
# 		metric:	P: 15.10	R:  5.84	F1:  8.42
# 	Hypothesis #18 & Reference #1:
# 		metric:	P: 12.09	R:  4.96	F1:  7.03
# 	Hypothesis #18 & Reference #2:
# 		metric:	P: 14.02	R:  5.36	F1:  7.76
# 	Hypothesis #18 & Reference #3:
# 		metric:	P: 12.09	R:  4.73	F1:  6.80
# 	Hypothesis #19 & Reference #0:
# 		metric:	P: 11.53	R:  4.62	F1:  6.60
# 	Hypothesis #19 & Reference #1:
# 		metric:	P: 13.68	R:  5.54	F1:  7.89
# 	Hypothesis #19 & Reference #2:
# 		metric:	P: 11.75	R:  4.65	F1:  6.66
# 	Hypothesis #19 & Reference #3:
# 		metric:	P: 13.42	R:  5.25	F1:  7.55
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 13.50	R:  5.89	F1:  8.20
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 16.49	R:  6.68	F1:  9.51
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  9.06	R:  3.63	F1:  5.18
# 	Hypothesis #20 & Reference #3:
# 		metric:	P: 13.34	R:  5.47	F1:  7.76
# 	Hypothesis #21 & Reference #0:
# 		metric:	P: 11.68	R:  4.70	F1:  6.70
# 	Hypothesis #21 & Reference #1:
# 		metric:	P: 13.33	R:  5.23	F1:  7.51
# 	Hypothesis #21 & Reference #2:
# 		metric:	P: 11.68	R:  4.43	F1:  6.42
# 	Hypothesis #21 & Reference #3:
# 		metric:	P: 11.18	R:  4.44	F1:  6.36
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 17.67	R:  7.13	F1: 10.16
# 	Hypothesis #22 & Reference #1:
# 		metric:	P: 15.26	R:  6.23	F1:  8.85
# 	Hypothesis #22 & Reference #2:
# 		metric:	P: 15.36	R:  6.20	F1:  8.83
# 	Hypothesis #22 & Reference #3:
# 		metric:	P: 16.33	R:  6.83	F1:  9.63
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 20.21	R:  7.77	F1: 11.22
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 16.92	R:  6.74	F1:  9.64
# 	Hypothesis #23 & Reference #2:
# 		metric:	P: 18.08	R:  6.71	F1:  9.79
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 20.14	R:  7.83	F1: 11.27
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 17.23	R:  6.86	F1:  9.81
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 18.85	R:  7.51	F1: 10.74
# 	Hypothesis #24 & Reference #2:
# 		metric:	P: 13.10	R:  5.15	F1:  7.39
# 	Hypothesis #24 & Reference #3:
# 		metric:	P: 13.80	R:  5.24	F1:  7.60
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  9.92	R:  3.94	F1:  5.64
# 	Hypothesis #25 & Reference #1:
# 		metric:	P: 11.97	R:  4.81	F1:  6.86
# 	Hypothesis #25 & Reference #2:
# 		metric:	P: 12.33	R:  4.90	F1:  7.01
# 	Hypothesis #25 & Reference #3:
# 		metric:	P: 10.44	R:  4.15	F1:  5.94
# 	Hypothesis #26 & Reference #0:
# 		metric:	P: 12.21	R:  4.89	F1:  6.98
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 19.53	R:  8.51	F1: 11.86
# 	Hypothesis #26 & Reference #2:
# 		metric:	P: 17.53	R:  7.02	F1: 10.02
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 17.78	R:  7.29	F1: 10.34
# 	Hypothesis #27 & Reference #0:
# 		metric:	P: 21.02	R:  8.32	F1: 11.92
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 22.24	R:  8.70	F1: 12.51
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 23.81	R:  9.42	F1: 13.50
# 	Hypothesis #27 & Reference #3:
# 		metric:	P: 15.76	R:  6.24	F1:  8.94
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 19.63	R:  7.62	F1: 10.98
# 	Hypothesis #28 & Reference #1:
# 		metric:	P: 10.81	R:  4.56	F1:  6.42
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 15.39	R:  6.12	F1:  8.75
# 	Hypothesis #28 & Reference #3:
# 		metric:	P: 13.88	R:  5.26	F1:  7.63
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 22.05	R:  8.81	F1: 12.59
# 	Hypothesis #29 & Reference #1:
# 		metric:	P: 14.76	R:  5.97	F1:  8.50
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 14.76	R:  5.97	F1:  8.50
# 	Hypothesis #29 & Reference #3:
# 		metric:	P: 17.69	R:  7.24	F1: 10.27
# 	Hypothesis #30 & Reference #0:
# 		metric:	P: 13.19	R:  5.11	F1:  7.37
# 	Hypothesis #30 & Reference #1:
# 		metric:	P: 17.61	R:  6.90	F1:  9.92
# 	Hypothesis #30 & Reference #2:
# 		metric:	P: 13.80	R:  5.35	F1:  7.71
# 	Hypothesis #30 & Reference #3:
# 		metric:	P: 15.24	R:  5.52	F1:  8.10
# 	Hypothesis #31 & Reference #0:
# 		metric:	P: 13.47	R:  5.21	F1:  7.51
# 	Hypothesis #31 & Reference #1:
# 		metric:	P: 12.51	R:  4.95	F1:  7.10
# 	Hypothesis #31 & Reference #2:
# 		metric:	P: 12.07	R:  4.61	F1:  6.68
# 	Hypothesis #31 & Reference #3:
# 		metric:	P: 11.08	R:  4.44	F1:  6.34
# 	Hypothesis #32 & Reference #0:
# 		metric:	P: 13.93	R:  5.22	F1:  7.60
# 	Hypothesis #32 & Reference #1:
# 		metric:	P: 14.38	R:  5.52	F1:  7.97
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 19.82	R:  7.52	F1: 10.90
# 	Hypothesis #32 & Reference #3:
# 		metric:	P: 11.61	R:  4.61	F1:  6.60
# 	Hypothesis #33 & Reference #0:
# 		metric:	P: 10.55	R:  4.39	F1:  6.20
# 	Hypothesis #33 & Reference #1:
# 		metric:	P: 13.96	R:  6.02	F1:  8.41
# 	Hypothesis #33 & Reference #2:
# 		metric:	P: 11.35	R:  4.78	F1:  6.73
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 14.97	R:  6.01	F1:  8.58
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 16.40	R:  6.50	F1:  9.31
# 	Hypothesis #34 & Reference #1:
# 		metric:	P: 12.92	R:  5.31	F1:  7.53
# 	Hypothesis #34 & Reference #2:
# 		metric:	P: 13.12	R:  5.20	F1:  7.45
# 	Hypothesis #34 & Reference #3:
# 		metric:	P: 11.20	R:  4.49	F1:  6.41
# 	Hypothesis #35 & Reference #0:
# 		metric:	P: 14.72	R:  6.03	F1:  8.55
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 18.83	R:  7.45	F1: 10.68
# 	Hypothesis #35 & Reference #2:
# 		metric:	P: 14.90	R:  5.65	F1:  8.19
# 	Hypothesis #35 & Reference #3:
# 		metric:	P: 12.41	R:  5.20	F1:  7.33
# 	Hypothesis #36 & Reference #0:
# 		metric:	P: 13.70	R:  5.60	F1:  7.95
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  9.44	R:  3.86	F1:  5.48
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  9.20	R:  3.81	F1:  5.39
# 	Hypothesis #36 & Reference #3:
# 		metric:	P: 11.76	R:  4.76	F1:  6.77
# 	Hypothesis #37 & Reference #0:
# 		metric:	P: 16.71	R:  6.71	F1:  9.57
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 22.87	R:  9.18	F1: 13.10
# 	Hypothesis #37 & Reference #2:
# 		metric:	P: 15.17	R:  6.16	F1:  8.76
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 19.53	R:  7.83	F1: 11.18
# 	Hypothesis #38 & Reference #0:
# 		metric:	P: 12.51	R:  4.96	F1:  7.10
# 	Hypothesis #38 & Reference #1:
# 		metric:	P: 14.29	R:  5.60	F1:  8.05
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 14.54	R:  5.70	F1:  8.19
# 	Hypothesis #38 & Reference #3:
# 		metric:	P: 12.69	R:  4.81	F1:  6.97
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 31.68	R: 12.99	F1: 18.42
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 20.80	R:  8.33	F1: 11.90
# 	Hypothesis #39 & Reference #2:
# 		metric:	P: 13.54	R:  5.55	F1:  7.88
# 	Hypothesis #39 & Reference #3:
# 		metric:	P: 14.21	R:  5.49	F1:  7.92
# 	Hypothesis #40 & Reference #0:
# 		metric:	P: 16.34	R:  6.26	F1:  9.05
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 20.11	R:  7.98	F1: 11.42
# 	Hypothesis #40 & Reference #2:
# 		metric:	P: 14.24	R:  5.39	F1:  7.82
# 	Hypothesis #40 & Reference #3:
# 		metric:	P: 12.20	R:  4.78	F1:  6.87
# 	Hypothesis #41 & Reference #0:
# 		metric:	P: 15.20	R:  6.12	F1:  8.72
# 	Hypothesis #41 & Reference #1:
# 		metric:	P: 11.74	R:  4.72	F1:  6.74
# 	Hypothesis #41 & Reference #2:
# 		metric:	P: 11.58	R:  4.66	F1:  6.65
# 	Hypothesis #41 & Reference #3:
# 		metric:	P: 11.39	R:  4.69	F1:  6.65
# 	Hypothesis #42 & Reference #0:
# 		metric:	P: 13.95	R:  5.41	F1:  7.80
# 	Hypothesis #42 & Reference #1:
# 		metric:	P: 16.49	R:  6.63	F1:  9.46
# 	Hypothesis #42 & Reference #2:
# 		metric:	P: 15.83	R:  6.14	F1:  8.85
# 	Hypothesis #42 & Reference #3:
# 		metric:	P: 14.71	R:  5.85	F1:  8.37
# 	Hypothesis #43 & Reference #0:
# 		metric:	P: 14.17	R:  5.70	F1:  8.13
# 	Hypothesis #43 & Reference #1:
# 		metric:	P: 14.44	R:  5.67	F1:  8.14
# 	Hypothesis #43 & Reference #2:
# 		metric:	P: 11.61	R:  4.61	F1:  6.60
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 12.33	R:  4.68	F1:  6.78
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 14.64	R:  5.81	F1:  8.32
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 14.10	R:  5.60	F1:  8.02
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 13.94	R:  5.54	F1:  7.93
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 13.18	R:  5.24	F1:  7.49
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  9.42	R:  3.77	F1:  5.38
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 12.69	R:  4.97	F1:  7.14
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 17.35	R:  7.03	F1: 10.00
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  9.28	R:  3.76	F1:  5.35
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 12.49	R:  5.01	F1:  7.15
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 13.27	R:  4.97	F1:  7.23
# 	Hypothesis #46 & Reference #2:
# 		metric:	P:  9.67	R:  3.75	F1:  5.40
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 14.23	R:  5.71	F1:  8.15
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 12.10	R:  4.87	F1:  6.94
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 15.32	R:  5.95	F1:  8.57
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 11.46	R:  4.55	F1:  6.52
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 13.25	R:  5.20	F1:  7.47
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 16.66	R:  6.58	F1:  9.44
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 17.31	R:  6.92	F1:  9.89
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 18.18	R:  7.27	F1: 10.38
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 14.01	R:  5.47	F1:  7.87
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 12.05	R:  4.65	F1:  6.71
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 13.48	R:  5.39	F1:  7.70
# 	Hypothesis #49 & Reference #2:
# 		metric:	P:  8.82	R:  3.57	F1:  5.08
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 12.66	R:  5.12	F1:  7.29
#
#
# None

# %% [markdown]
# ## Evaluate using Word Embeddings Trained on the Corpus (dim = 300)

# %%
# Sentence tokenize t
import nltk.data
import preprocessor3

# Compound all docs into a megadocument to process
megadoc = ""
for set_id in corpus:
    for article in corpus[set_id]['articles']:
        megadoc += article
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
pre = preprocessor3.spacy_preprocessor()
megadoc_sents = sent_detector.tokenize(megadoc)
embeddings_corpus = pre.preprocess_texts(megadoc_sents, tags=[])

# %%
model = Word2Vec(embeddings_corpus, size=300, window=5, min_count=1, workers=-1) 
summarizer = centroid_word_embeddings.CentroidWordEmbeddingsSummarizer(model, parser = parser)

# %%
SET_ID = 0
compound_article = ''.join(corpus[list(corpus.keys())[SET_ID]]['articles'])
print(summarizer.summarize(compound_article))
# Out:
# [(22, 0.75969136), (5, 0.06407431), (4, 0.04172836), (30, 0.037224017), (11, 0.035380177), (16, 0.022310968), (14, 0.02006666)]
# Cambodian leader Hun Sen on Friday rejected opposition parties' demands for talks outside the country, accusing them of trying to ``internationalize'' the political crisis.
# Government and opposition parties have asked King Norodom Sihanouk to host a summit meeting after a series of post-election negotiations between the two opposition groups and Hun Sen's party to form a new government failed.
# Opposition leaders Prince Norodom Ranariddh and Sam Rainsy, citing Hun Sen's threats to arrest opposition figures after two alleged attempts on his life, said they could not negotiate freely in Cambodia and called for talks at Sihanouk's residence in Beijing.
# Hun Sen, however, rejected that.

# %%
import rouge_evaluator3
hypos = []
refs = []
for set_id in corpus.keys():
    hypos.append(summarizer.summarize(''.join(corpus[set_id]['articles'])))
    refs.append(corpus[set_id]['summaries'])
print(rouge_evaluator3.evaluate_hypotheses(hypos, refs))
# Out:
# [(22, 0.759689), (5, 0.06407002), (4, 0.04172391), (30, 0.037218664), (11, 0.03537825), (16, 0.022312341), (14, 0.020062424)]
# [(19, 0.4943709), (28, 0.21851768), (6, 0.13177583), (16, 0.055854294), (14, 0.028849978), (17, 0.026714142), (9, 0.022487836)]
# [(13, 0.38443038), (26, 0.3403188), (30, 0.08275759), (3, 0.0640601), (7, 0.048878744), (11, 0.04609058), (0, 0.013568831)]
# [(3, 0.7701665), (9, 0.05115599), (19, 0.04287007), (28, 0.0397353), (26, 0.036871504), (10, 0.023494737), (21, 0.015730012), (5, 0.0137548605)]
# [(17, 0.5576531), (13, 0.31476846), (22, 0.036934968), (14, 0.036477823), (30, 0.027896233), (26, 0.01454247)]
# [(16, 0.77831584), (21, 0.10548456), (12, 0.04205644), (17, 0.0268977), (28, 0.022566233), (5, 0.012414201)]
# [(19, 0.7661748), (17, 0.070735894), (30, 0.02642394), (22, 0.022989243), (5, 0.020693133), (24, 0.019517612), (0, 0.016679455), (16, 0.015349585), (4, 0.014056343), (14, 0.012249204)]
# [(16, 0.66534144), (28, 0.24725011), (23, 0.07041433)]
# [(19, 0.6078118), (30, 0.10849149), (0, 0.08592387), (14, 0.078669704), (11, 0.039325956), (28, 0.031060964), (17, 0.018613419)]
# [(5, 0.83010757), (16, 0.13720909), (26, 0.026403375)]
# [(15, 0.31305155), (9, 0.3104672), (29, 0.10629133), (3, 0.05419493), (17, 0.04428794), (31, 0.032529913), (23, 0.031347435), (19, 0.025422987), (22, 0.022978555), (30, 0.01786197), (28, 0.015680302), (21, 0.015111124)]
# [(21, 0.50236213), (0, 0.10517506), (5, 0.10471285), (4, 0.07836407), (22, 0.076805584), (19, 0.027753403), (23, 0.024195896), (18, 0.01873988), (3, 0.01776552), (12, 0.014252619), (13, 0.0120635)]
# [(30, 0.8090881), (24, 0.061781973), (19, 0.054552842), (4, 0.027887661), (28, 0.024622578)]
# [(4, 0.8297961), (9, 0.05144206), (18, 0.038762134), (16, 0.025236037), (21, 0.012876633), (6, 0.010926492)]
# [(24, 0.5548606), (29, 0.30335853), (12, 0.04308159), (15, 0.031591214), (23, 0.02885771), (4, 0.016384779)]
# [(19, 0.6028576), (17, 0.089988366), (24, 0.05913221), (29, 0.055396106), (1, 0.03767927), (18, 0.036565475), (5, 0.032150954), (4, 0.028330809), (21, 0.013985637), (3, 0.012385877)]
# [(10, 0.8600462), (13, 0.11154711), (5, 0.01565467)]
# [(14, 0.8242219), (11, 0.13329305), (6, 0.035189975)]
# [(25, 0.61558825), (12, 0.28966862), (24, 0.04851952), (26, 0.032191202), (23, 0.01378356)]
# [(22, 0.33967453), (19, 0.301083), (18, 0.1649455), (31, 0.048122186), (17, 0.04438818), (28, 0.0304766), (0, 0.024243912), (23, 0.019889439), (4, 0.01741934)]
# [(16, 0.5666807), (3, 0.27576527), (15, 0.07026137), (9, 0.05057172), (30, 0.010329505)]
# [(20, 0.42388055), (22, 0.21896163), (27, 0.11403157), (29, 0.09719648), (14, 0.06453261), (1, 0.03756863), (4, 0.018078422), (13, 0.016235089)]
# [(16, 0.41550016), (13, 0.3497525), (12, 0.09654662), (17, 0.03851736), (3, 0.03331237), (7, 0.02819361), (2, 0.020589013), (22, 0.01409272)]
# [(21, 0.9152654), (22, 0.026756138), (14, 0.02316783), (20, 0.020660225), (29, 0.011072647)]
# [(16, 0.7280257), (8, 0.19696036), (30, 0.046658736), (17, 0.02307368)]
# [(28, 0.78925496), (25, 0.06382245), (0, 0.04448857), (5, 0.04114041), (4, 0.025384441), (26, 0.012722209), (29, 0.012450527)]
# [(10, 0.5936341), (28, 0.08968487), (30, 0.07220447), (19, 0.05914216), (6, 0.04728968), (11, 0.04553034), (24, 0.03306778), (2, 0.02032034), (9, 0.012191693), (22, 0.011224338)]
# [(17, 0.86975706), (24, 0.053647537), (19, 0.029251901), (13, 0.023995943), (0, 0.01863266)]
# [(4, 0.60509485), (17, 0.08612473), (5, 0.06634795), (30, 0.064670555), (9, 0.06223878), (3, 0.029504167), (21, 0.020531017), (8, 0.01964321), (6, 0.018711273)]
# [(12, 0.44348153), (25, 0.39970493), (24, 0.113931574), (26, 0.032356795)]
# [(19, 0.88403976), (4, 0.04146915), (31, 0.02907445), (18, 0.023266973), (24, 0.01128476)]
# [(9, 0.821952), (19, 0.07471283), (29, 0.054087583), (3, 0.041621096)]
# [(7, 0.2659896), (4, 0.26035345), (15, 0.16812122), (23, 0.07034789), (30, 0.045444336), (16, 0.03950666), (17, 0.03588962), (26, 0.033390317), (24, 0.021777235), (28, 0.016465427), (3, 0.011946385), (5, 0.010313522)]
# [(11, 0.5942737), (19, 0.16846931), (5, 0.1125706), (16, 0.04892107), (4, 0.026812952), (22, 0.018880323), (15, 0.014507847), (30, 0.013031423)]
# [(16, 0.8153558), (5, 0.14152631), (17, 0.02419362)]
# [(2, 0.9048408), (5, 0.038539406), (23, 0.018755995), (25, 0.014389754)]
# [(7, 0.7559981), (5, 0.16124997), (29, 0.02591597), (16, 0.019106051), (4, 0.012401131), (10, 0.0115558375)]
# [(7, 0.5915293), (30, 0.13860469), (4, 0.05416191), (16, 0.051785666), (12, 0.048358034), (20, 0.030377721), (10, 0.020876303), (3, 0.014787849), (19, 0.013908272), (27, 0.013409398)]
# [(18, 0.43986195), (4, 0.18278463), (13, 0.10028948), (29, 0.08821189), (7, 0.049190633), (26, 0.04506978), (30, 0.042533208), (11, 0.019245952), (17, 0.013118947)]
# [(23, 0.493175), (4, 0.30373996), (5, 0.07496216), (24, 0.061722472), (7, 0.05979204)]
# [(2, 0.3839113), (22, 0.19401675), (10, 0.18494736), (24, 0.08335076), (4, 0.07912292), (18, 0.03834082), (28, 0.012849133)]
# [(17, 0.75541157), (4, 0.042212903), (23, 0.041744985), (27, 0.0373482), (11, 0.03289135), (7, 0.031439587), (3, 0.01805405)]
# [(4, 0.99522036)]
# [(6, 0.4400345), (17, 0.26827124), (29, 0.09738277), (24, 0.07641025), (11, 0.05869579), (12, 0.043211997), (20, 0.015287772)]
# [(20, 0.4029368), (4, 0.17277026), (18, 0.15696977), (30, 0.0778118), (3, 0.054992888), (17, 0.037082437), (24, 0.023814075), (19, 0.023646146), (26, 0.021324757), (29, 0.015533893)]
# [(10, 0.4972256), (5, 0.21386991), (19, 0.08393541), (7, 0.07060345), (3, 0.063630484), (4, 0.023267042), (29, 0.015494522), (2, 0.012937412)]
# [(24, 0.6826695), (27, 0.2037468), (3, 0.0444807), (4, 0.020751499), (17, 0.013711066), (25, 0.0120397555), (21, 0.011341151)]
# [(3, 0.5625006), (26, 0.27630875), (6, 0.05575259), (5, 0.053635538), (22, 0.03161188), (11, 0.01536634)]
# [(14, 0.64465576), (5, 0.20466593), (16, 0.071308225), (26, 0.032980677), (10, 0.027959833), (2, 0.01688325)]
# [(30, 0.64442116), (28, 0.079078384), (25, 0.055357147), (13, 0.044968996), (6, 0.043169968), (24, 0.035536893), (4, 0.034265637), (19, 0.022178905), (29, 0.012881809), (9, 0.011815202)]
# Evaluation with Avg
# 	metric:	P: 31.63	R: 31.85	F1: 31.74
# 	metric:	P:  6.39	R:  6.44	F1:  6.41
# 	metric:	P:  2.03	R:  2.05	F1:  2.04
# 	metric:	P:  0.81	R:  0.82	F1:  0.81
# 	metric:	P: 26.88	R: 27.04	F1: 26.96
# 	metric:	P: 13.97	R:  5.58	F1:  7.97
#
# Evaluation with Best
# 	metric:	P: 35.98	R: 36.29	F1: 36.13
# 	metric:	P: 10.20	R: 10.28	F1: 10.24
# 	metric:	P:  4.54	R:  4.58	F1:  4.56
# 	metric:	P:  2.42	R:  2.44	F1:  2.43
# 	metric:	P: 30.79	R: 31.05	F1: 30.91
# 	metric:	P: 16.75	R:  6.70	F1:  9.57
#
# Evaluation with Individual
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 42.31	R: 42.31	F1: 42.31
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 49.04	R: 50.00	F1: 49.51
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 42.31	R: 44.00	F1: 43.14
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 42.31	R: 43.56	F1: 42.93
# 	Hypothesis #1 & Reference #0:
# 		metric:	P: 30.30	R: 28.04	F1: 29.13
# 	Hypothesis #1 & Reference #1:
# 		metric:	P: 27.27	R: 25.47	F1: 26.34
# 	Hypothesis #1 & Reference #2:
# 		metric:	P: 26.26	R: 25.24	F1: 25.74
# 	Hypothesis #1 & Reference #3:
# 		metric:	P: 34.34	R: 32.38	F1: 33.33
# 	Hypothesis #2 & Reference #0:
# 		metric:	P: 33.66	R: 33.33	F1: 33.50
# 	Hypothesis #2 & Reference #1:
# 		metric:	P: 29.70	R: 29.41	F1: 29.56
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 37.62	R: 37.25	F1: 37.44
# 	Hypothesis #2 & Reference #3:
# 		metric:	P: 27.72	R: 28.87	F1: 28.28
# 	Hypothesis #3 & Reference #0:
# 		metric:	P: 29.81	R: 29.52	F1: 29.67
# 	Hypothesis #3 & Reference #1:
# 		metric:	P: 22.12	R: 22.55	F1: 22.33
# 	Hypothesis #3 & Reference #2:
# 		metric:	P: 21.15	R: 21.57	F1: 21.36
# 	Hypothesis #3 & Reference #3:
# 		metric:	P: 24.04	R: 24.27	F1: 24.15
# 	Hypothesis #4 & Reference #0:
# 		metric:	P: 27.45	R: 28.00	F1: 27.72
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 33.33	R: 34.00	F1: 33.66
# 	Hypothesis #4 & Reference #2:
# 		metric:	P: 27.45	R: 27.45	F1: 27.45
# 	Hypothesis #4 & Reference #3:
# 		metric:	P: 31.37	R: 31.07	F1: 31.22
# 	Hypothesis #5 & Reference #0:
# 		metric:	P: 30.69	R: 30.39	F1: 30.54
# 	Hypothesis #5 & Reference #1:
# 		metric:	P: 21.78	R: 22.22	F1: 22.00
# 	Hypothesis #5 & Reference #2:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #5 & Reference #3:
# 		metric:	P: 23.76	R: 23.53	F1: 23.65
# 	Hypothesis #6 & Reference #0:
# 		metric:	P: 31.19	R: 32.69	F1: 31.92
# 	Hypothesis #6 & Reference #1:
# 		metric:	P: 26.61	R: 28.71	F1: 27.62
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 37.61	R: 40.59	F1: 39.05
# 	Hypothesis #6 & Reference #3:
# 		metric:	P: 29.36	R: 30.77	F1: 30.05
# 	Hypothesis #7 & Reference #0:
# 		metric:	P: 34.62	R: 36.73	F1: 35.64
# 	Hypothesis #7 & Reference #1:
# 		metric:	P: 39.42	R: 41.41	F1: 40.39
# 	Hypothesis #7 & Reference #2:
# 		metric:	P: 32.69	R: 34.00	F1: 33.33
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 34.62	R: 36.36	F1: 35.47
# 	Hypothesis #8 & Reference #0:
# 		metric:	P: 29.41	R: 30.30	F1: 29.85
# 	Hypothesis #8 & Reference #1:
# 		metric:	P: 20.59	R: 20.19	F1: 20.39
# 	Hypothesis #8 & Reference #2:
# 		metric:	P: 26.47	R: 26.47	F1: 26.47
# 	Hypothesis #8 & Reference #3:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #9 & Reference #0:
# 		metric:	P: 25.00	R: 24.27	F1: 24.63
# 	Hypothesis #9 & Reference #1:
# 		metric:	P: 26.00	R: 26.00	F1: 26.00
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 33.00	R: 31.43	F1: 32.20
# 	Hypothesis #9 & Reference #3:
# 		metric:	P: 27.00	R: 26.21	F1: 26.60
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 35.24	R: 35.92	F1: 35.58
# 	Hypothesis #10 & Reference #1:
# 		metric:	P: 33.33	R: 34.31	F1: 33.82
# 	Hypothesis #10 & Reference #2:
# 		metric:	P: 29.52	R: 30.10	F1: 29.81
# 	Hypothesis #10 & Reference #3:
# 		metric:	P: 23.81	R: 25.00	F1: 24.39
# 	Hypothesis #11 & Reference #0:
# 		metric:	P: 31.37	R: 31.07	F1: 31.22
# 	Hypothesis #11 & Reference #1:
# 		metric:	P: 31.37	R: 32.00	F1: 31.68
# 	Hypothesis #11 & Reference #2:
# 		metric:	P: 23.53	R: 23.08	F1: 23.30
# 	Hypothesis #11 & Reference #3:
# 		metric:	P: 32.35	R: 31.73	F1: 32.04
# 	Hypothesis #12 & Reference #0:
# 		metric:	P: 31.73	R: 32.67	F1: 32.20
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 35.58	R: 36.27	F1: 35.92
# 	Hypothesis #12 & Reference #2:
# 		metric:	P: 26.92	R: 27.72	F1: 27.32
# 	Hypothesis #12 & Reference #3:
# 		metric:	P: 23.08	R: 23.30	F1: 23.19
# 	Hypothesis #13 & Reference #0:
# 		metric:	P: 34.65	R: 34.31	F1: 34.48
# 	Hypothesis #13 & Reference #1:
# 		metric:	P: 27.72	R: 27.45	F1: 27.59
# 	Hypothesis #13 & Reference #2:
# 		metric:	P: 31.68	R: 33.33	F1: 32.49
# 	Hypothesis #13 & Reference #3:
# 		metric:	P: 32.67	R: 31.73	F1: 32.20
# 	Hypothesis #14 & Reference #0:
# 		metric:	P: 24.53	R: 26.00	F1: 25.24
# 	Hypothesis #14 & Reference #1:
# 		metric:	P: 19.81	R: 22.11	F1: 20.90
# 	Hypothesis #14 & Reference #2:
# 		metric:	P: 29.25	R: 30.39	F1: 29.81
# 	Hypothesis #14 & Reference #3:
# 		metric:	P: 24.53	R: 25.49	F1: 25.00
# 	Hypothesis #15 & Reference #0:
# 		metric:	P: 15.45	R: 17.71	F1: 16.50
# 	Hypothesis #15 & Reference #1:
# 		metric:	P: 20.91	R: 23.00	F1: 21.90
# 	Hypothesis #15 & Reference #2:
# 		metric:	P: 11.82	R: 13.13	F1: 12.44
# 	Hypothesis #15 & Reference #3:
# 		metric:	P: 19.09	R: 20.59	F1: 19.81
# 	Hypothesis #16 & Reference #0:
# 		metric:	P: 27.36	R: 28.16	F1: 27.75
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 31.13	R: 32.67	F1: 31.88
# 	Hypothesis #16 & Reference #2:
# 		metric:	P: 33.02	R: 33.65	F1: 33.33
# 	Hypothesis #16 & Reference #3:
# 		metric:	P: 25.47	R: 26.47	F1: 25.96
# 	Hypothesis #17 & Reference #0:
# 		metric:	P: 33.98	R: 33.33	F1: 33.65
# 	Hypothesis #17 & Reference #1:
# 		metric:	P: 24.27	R: 24.27	F1: 24.27
# 	Hypothesis #17 & Reference #2:
# 		metric:	P: 27.18	R: 26.67	F1: 26.92
# 	Hypothesis #17 & Reference #3:
# 		metric:	P: 31.07	R: 29.91	F1: 30.48
# 	Hypothesis #18 & Reference #0:
# 		metric:	P: 36.89	R: 36.19	F1: 36.54
# 	Hypothesis #18 & Reference #1:
# 		metric:	P: 31.07	R: 32.00	F1: 31.53
# 	Hypothesis #18 & Reference #2:
# 		metric:	P: 35.92	R: 34.91	F1: 35.41
# 	Hypothesis #18 & Reference #3:
# 		metric:	P: 27.18	R: 26.92	F1: 27.05
# 	Hypothesis #19 & Reference #0:
# 		metric:	P: 34.95	R: 35.29	F1: 35.12
# 	Hypothesis #19 & Reference #1:
# 		metric:	P: 33.01	R: 33.66	F1: 33.33
# 	Hypothesis #19 & Reference #2:
# 		metric:	P: 25.24	R: 25.24	F1: 25.24
# 	Hypothesis #19 & Reference #3:
# 		metric:	P: 35.92	R: 35.58	F1: 35.75
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 36.89	R: 40.00	F1: 38.38
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 38.83	R: 39.60	F1: 39.22
# 	Hypothesis #20 & Reference #2:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #20 & Reference #3:
# 		metric:	P: 34.95	R: 36.00	F1: 35.47
# 	Hypothesis #21 & Reference #0:
# 		metric:	P: 27.72	R: 28.00	F1: 27.86
# 	Hypothesis #21 & Reference #1:
# 		metric:	P: 33.66	R: 33.33	F1: 33.50
# 	Hypothesis #21 & Reference #2:
# 		metric:	P: 24.75	R: 23.81	F1: 24.27
# 	Hypothesis #21 & Reference #3:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 42.86	R: 43.69	F1: 43.27
# 	Hypothesis #22 & Reference #1:
# 		metric:	P: 35.24	R: 36.27	F1: 35.75
# 	Hypothesis #22 & Reference #2:
# 		metric:	P: 37.14	R: 37.86	F1: 37.50
# 	Hypothesis #22 & Reference #3:
# 		metric:	P: 35.24	R: 37.00	F1: 36.10
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 44.00	R: 42.72	F1: 43.35
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 41.00	R: 41.00	F1: 41.00
# 	Hypothesis #23 & Reference #2:
# 		metric:	P: 39.00	R: 36.79	F1: 37.86
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 42.00	R: 41.18	F1: 41.58
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 42.00	R: 42.00	F1: 42.00
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 38.00	R: 38.00	F1: 38.00
# 	Hypothesis #24 & Reference #2:
# 		metric:	P: 32.00	R: 31.68	F1: 31.84
# 	Hypothesis #24 & Reference #3:
# 		metric:	P: 36.00	R: 34.62	F1: 35.29
# 	Hypothesis #25 & Reference #0:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #25 & Reference #1:
# 		metric:	P: 23.76	R: 24.00	F1: 23.88
# 	Hypothesis #25 & Reference #2:
# 		metric:	P: 26.73	R: 26.73	F1: 26.73
# 	Hypothesis #25 & Reference #3:
# 		metric:	P: 24.75	R: 24.75	F1: 24.75
# 	Hypothesis #26 & Reference #0:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 39.81	R: 43.16	F1: 41.41
# 	Hypothesis #26 & Reference #2:
# 		metric:	P: 43.69	R: 44.12	F1: 43.90
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 36.89	R: 38.00	F1: 37.44
# 	Hypothesis #27 & Reference #0:
# 		metric:	P: 41.75	R: 41.75	F1: 41.75
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 46.60	R: 46.15	F1: 46.38
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 46.60	R: 46.60	F1: 46.60
# 	Hypothesis #27 & Reference #3:
# 		metric:	P: 39.81	R: 39.81	F1: 39.81
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 36.63	R: 35.92	F1: 36.27
# 	Hypothesis #28 & Reference #1:
# 		metric:	P: 33.66	R: 35.42	F1: 34.52
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 38.61	R: 38.61	F1: 38.61
# 	Hypothesis #28 & Reference #3:
# 		metric:	P: 36.63	R: 35.24	F1: 35.92
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 44.23	R: 44.66	F1: 44.44
# 	Hypothesis #29 & Reference #1:
# 		metric:	P: 36.54	R: 37.25	F1: 36.89
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 35.58	R: 36.27	F1: 35.92
# 	Hypothesis #29 & Reference #3:
# 		metric:	P: 45.19	R: 46.53	F1: 45.85
# 	Hypothesis #30 & Reference #0:
# 		metric:	P: 29.41	R: 28.85	F1: 29.13
# 	Hypothesis #30 & Reference #1:
# 		metric:	P: 36.27	R: 35.92	F1: 36.10
# 	Hypothesis #30 & Reference #2:
# 		metric:	P: 31.37	R: 30.77	F1: 31.07
# 	Hypothesis #30 & Reference #3:
# 		metric:	P: 37.25	R: 34.55	F1: 35.85
# 	Hypothesis #31 & Reference #0:
# 		metric:	P: 30.10	R: 29.52	F1: 29.81
# 	Hypothesis #31 & Reference #1:
# 		metric:	P: 28.16	R: 28.16	F1: 28.16
# 	Hypothesis #31 & Reference #2:
# 		metric:	P: 25.24	R: 24.53	F1: 24.88
# 	Hypothesis #31 & Reference #3:
# 		metric:	P: 25.24	R: 25.49	F1: 25.37
# 	Hypothesis #32 & Reference #0:
# 		metric:	P: 29.70	R: 28.30	F1: 28.99
# 	Hypothesis #32 & Reference #1:
# 		metric:	P: 30.69	R: 29.81	F1: 30.24
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 39.60	R: 38.10	F1: 38.83
# 	Hypothesis #32 & Reference #3:
# 		metric:	P: 29.70	R: 29.70	F1: 29.70
# 	Hypothesis #33 & Reference #0:
# 		metric:	P: 26.17	R: 27.45	F1: 26.79
# 	Hypothesis #33 & Reference #1:
# 		metric:	P: 26.17	R: 28.28	F1: 27.18
# 	Hypothesis #33 & Reference #2:
# 		metric:	P: 18.69	R: 19.80	F1: 19.23
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 26.17	R: 26.67	F1: 26.42
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 35.29	R: 35.29	F1: 35.29
# 	Hypothesis #34 & Reference #1:
# 		metric:	P: 35.29	R: 36.36	F1: 35.82
# 	Hypothesis #34 & Reference #2:
# 		metric:	P: 32.35	R: 32.35	F1: 32.35
# 	Hypothesis #34 & Reference #3:
# 		metric:	P: 24.51	R: 24.75	F1: 24.63
# 	Hypothesis #35 & Reference #0:
# 		metric:	P: 33.94	R: 35.24	F1: 34.58
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 45.87	R: 46.30	F1: 46.08
# 	Hypothesis #35 & Reference #2:
# 		metric:	P: 38.53	R: 37.50	F1: 38.01
# 	Hypothesis #35 & Reference #3:
# 		metric:	P: 33.94	R: 35.92	F1: 34.91
# 	Hypothesis #36 & Reference #0:
# 		metric:	P: 25.00	R: 25.74	F1: 25.37
# 	Hypothesis #36 & Reference #1:
# 		metric:	P: 25.00	R: 25.74	F1: 25.37
# 	Hypothesis #36 & Reference #2:
# 		metric:	P: 22.12	R: 23.00	F1: 22.55
# 	Hypothesis #36 & Reference #3:
# 		metric:	P: 22.12	R: 22.55	F1: 22.33
# 	Hypothesis #37 & Reference #0:
# 		metric:	P: 42.16	R: 42.57	F1: 42.36
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 50.00	R: 50.50	F1: 50.25
# 	Hypothesis #37 & Reference #2:
# 		metric:	P: 31.37	R: 32.00	F1: 31.68
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 44.12	R: 44.55	F1: 44.33
# 	Hypothesis #38 & Reference #0:
# 		metric:	P: 27.45	R: 27.45	F1: 27.45
# 	Hypothesis #38 & Reference #1:
# 		metric:	P: 35.29	R: 34.95	F1: 35.12
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #38 & Reference #3:
# 		metric:	P: 31.37	R: 30.19	F1: 30.77
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 55.34	R: 57.00	F1: 56.16
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 44.66	R: 45.10	F1: 44.88
# 	Hypothesis #39 & Reference #2:
# 		metric:	P: 32.04	R: 33.00	F1: 32.51
# 	Hypothesis #39 & Reference #3:
# 		metric:	P: 26.21	R: 25.71	F1: 25.96
# 	Hypothesis #40 & Reference #0:
# 		metric:	P: 35.29	R: 34.29	F1: 34.78
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 38.24	R: 38.24	F1: 38.24
# 	Hypothesis #40 & Reference #2:
# 		metric:	P: 32.35	R: 31.13	F1: 31.73
# 	Hypothesis #40 & Reference #3:
# 		metric:	P: 32.35	R: 32.04	F1: 32.20
# 	Hypothesis #41 & Reference #0:
# 		metric:	P: 31.13	R: 31.73	F1: 31.43
# 	Hypothesis #41 & Reference #1:
# 		metric:	P: 32.08	R: 32.69	F1: 32.38
# 	Hypothesis #41 & Reference #2:
# 		metric:	P: 31.13	R: 31.73	F1: 31.43
# 	Hypothesis #41 & Reference #3:
# 		metric:	P: 21.70	R: 22.55	F1: 22.12
# 	Hypothesis #42 & Reference #0:
# 		metric:	P: 36.63	R: 35.92	F1: 36.27
# 	Hypothesis #42 & Reference #1:
# 		metric:	P: 36.63	R: 37.00	F1: 36.82
# 	Hypothesis #42 & Reference #2:
# 		metric:	P: 31.68	R: 31.07	F1: 31.37
# 	Hypothesis #42 & Reference #3:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #43 & Reference #0:
# 		metric:	P: 28.71	R: 29.00	F1: 28.86
# 	Hypothesis #43 & Reference #1:
# 		metric:	P: 31.68	R: 31.37	F1: 31.53
# 	Hypothesis #43 & Reference #2:
# 		metric:	P: 21.78	R: 21.78	F1: 21.78
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 26.73	R: 25.71	F1: 26.21
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 34.65	R: 34.65	F1: 34.65
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 32.67	R: 32.67	F1: 32.67
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 33.66	R: 33.66	F1: 33.66
# 	Hypothesis #45 & Reference #0:
# 		metric:	P: 20.39	R: 20.59	F1: 20.49
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 27.18	R: 26.92	F1: 27.05
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 31.07	R: 31.68	F1: 31.37
# 	Hypothesis #45 & Reference #3:
# 		metric:	P: 19.42	R: 19.80	F1: 19.61
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 30.39	R: 30.69	F1: 30.54
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 30.39	R: 28.97	F1: 29.67
# 	Hypothesis #46 & Reference #2:
# 		metric:	P: 22.55	R: 22.12	F1: 22.33
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 31.37	R: 31.68	F1: 31.53
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 28.71	R: 29.00	F1: 28.86
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 30.69	R: 30.10	F1: 30.39
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 25.74	R: 25.74	F1: 25.74
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 29.70	R: 29.41	F1: 29.56
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 38.46	R: 38.46	F1: 38.46
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 39.42	R: 39.81	F1: 39.61
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 39.42	R: 39.81	F1: 39.61
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 33.65	R: 33.33	F1: 33.49
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 25.00	R: 24.53	F1: 24.76
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 26.92	R: 27.18	F1: 27.05
# 	Hypothesis #49 & Reference #2:
# 		metric:	P: 19.23	R: 19.61	F1: 19.42
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 25.96	R: 26.47	F1: 26.21
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 12.62	R: 12.62	F1: 12.62
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 11.65	R: 11.88	F1: 11.76
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 12.62	R: 13.13	F1: 12.87
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 13.59	R: 14.00	F1: 13.79
# 	Hypothesis #1 & Reference #0:
# 		metric:	P:  5.10	R:  4.72	F1:  4.90
# 	Hypothesis #1 & Reference #1:
# 		metric:	P:  4.08	R:  3.81	F1:  3.94
# 	Hypothesis #1 & Reference #2:
# 		metric:	P:  4.08	R:  3.92	F1:  4.00
# 	Hypothesis #1 & Reference #3:
# 		metric:	P:  8.16	R:  7.69	F1:  7.92
# 	Hypothesis #2 & Reference #0:
# 		metric:	P:  7.00	R:  6.93	F1:  6.97
# 	Hypothesis #2 & Reference #1:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 10.00	R:  9.90	F1:  9.95
# 	Hypothesis #2 & Reference #3:
# 		metric:	P:  6.00	R:  6.25	F1:  6.12
# 	Hypothesis #3 & Reference #0:
# 		metric:	P:  7.77	R:  7.69	F1:  7.73
# 	Hypothesis #3 & Reference #1:
# 		metric:	P:  4.85	R:  4.95	F1:  4.90
# 	Hypothesis #3 & Reference #2:
# 		metric:	P:  5.83	R:  5.94	F1:  5.88
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  1.94	R:  1.96	F1:  1.95
# 	Hypothesis #4 & Reference #0:
# 		metric:	P:  6.93	R:  7.07	F1:  7.00
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 10.89	R: 11.11	F1: 11.00
# 	Hypothesis #4 & Reference #2:
# 		metric:	P:  3.96	R:  3.96	F1:  3.96
# 	Hypothesis #4 & Reference #3:
# 		metric:	P:  5.94	R:  5.88	F1:  5.91
# 	Hypothesis #5 & Reference #0:
# 		metric:	P:  6.00	R:  5.94	F1:  5.97
# 	Hypothesis #5 & Reference #1:
# 		metric:	P:  1.00	R:  1.02	F1:  1.01
# 	Hypothesis #5 & Reference #2:
# 		metric:	P:  6.00	R:  6.00	F1:  6.00
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #6 & Reference #0:
# 		metric:	P:  6.48	R:  6.80	F1:  6.64
# 	Hypothesis #6 & Reference #1:
# 		metric:	P:  4.63	R:  5.00	F1:  4.81
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 12.04	R: 13.00	F1: 12.50
# 	Hypothesis #6 & Reference #3:
# 		metric:	P:  2.78	R:  2.91	F1:  2.84
# 	Hypothesis #7 & Reference #0:
# 		metric:	P:  5.83	R:  6.19	F1:  6.00
# 	Hypothesis #7 & Reference #1:
# 		metric:	P:  7.77	R:  8.16	F1:  7.96
# 	Hypothesis #7 & Reference #2:
# 		metric:	P:  6.80	R:  7.07	F1:  6.93
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 10.68	R: 11.22	F1: 10.95
# 	Hypothesis #8 & Reference #0:
# 		metric:	P:  4.95	R:  5.10	F1:  5.03
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #8 & Reference #2:
# 		metric:	P:  6.93	R:  6.93	F1:  6.93
# 	Hypothesis #8 & Reference #3:
# 		metric:	P:  6.93	R:  6.86	F1:  6.90
# 	Hypothesis #9 & Reference #0:
# 		metric:	P:  3.03	R:  2.94	F1:  2.99
# 	Hypothesis #9 & Reference #1:
# 		metric:	P:  6.06	R:  6.06	F1:  6.06
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 14.14	R: 13.46	F1: 13.79
# 	Hypothesis #9 & Reference #3:
# 		metric:	P:  6.06	R:  5.88	F1:  5.97
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 14.42	R: 14.71	F1: 14.56
# 	Hypothesis #10 & Reference #1:
# 		metric:	P:  1.92	R:  1.98	F1:  1.95
# 	Hypothesis #10 & Reference #2:
# 		metric:	P:  2.88	R:  2.94	F1:  2.91
# 	Hypothesis #10 & Reference #3:
# 		metric:	P:  3.85	R:  4.04	F1:  3.94
# 	Hypothesis #11 & Reference #0:
# 		metric:	P:  7.92	R:  7.84	F1:  7.88
# 	Hypothesis #11 & Reference #1:
# 		metric:	P:  2.97	R:  3.03	F1:  3.00
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  2.97	R:  2.91	F1:  2.94
# 	Hypothesis #11 & Reference #3:
# 		metric:	P:  3.96	R:  3.88	F1:  3.92
# 	Hypothesis #12 & Reference #0:
# 		metric:	P:  3.88	R:  4.00	F1:  3.94
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 17.48	R: 17.82	F1: 17.65
# 	Hypothesis #12 & Reference #2:
# 		metric:	P:  5.83	R:  6.00	F1:  5.91
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  1.94	R:  1.96	F1:  1.95
# 	Hypothesis #13 & Reference #0:
# 		metric:	P:  7.00	R:  6.93	F1:  6.97
# 	Hypothesis #13 & Reference #1:
# 		metric:	P:  4.00	R:  3.96	F1:  3.98
# 	Hypothesis #13 & Reference #2:
# 		metric:	P:  5.00	R:  5.26	F1:  5.13
# 	Hypothesis #13 & Reference #3:
# 		metric:	P:  2.00	R:  1.94	F1:  1.97
# 	Hypothesis #14 & Reference #0:
# 		metric:	P:  3.81	R:  4.04	F1:  3.92
# 	Hypothesis #14 & Reference #1:
# 		metric:	P:  2.86	R:  3.19	F1:  3.02
# 	Hypothesis #14 & Reference #2:
# 		metric:	P:  7.62	R:  7.92	F1:  7.77
# 	Hypothesis #14 & Reference #3:
# 		metric:	P:  2.86	R:  2.97	F1:  2.91
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  0.92	R:  1.05	F1:  0.98
# 	Hypothesis #15 & Reference #1:
# 		metric:	P:  1.83	R:  2.02	F1:  1.92
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  0.92	R:  0.99	F1:  0.95
# 	Hypothesis #16 & Reference #0:
# 		metric:	P:  4.76	R:  4.90	F1:  4.83
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 10.48	R: 11.00	F1: 10.73
# 	Hypothesis #16 & Reference #2:
# 		metric:	P:  8.57	R:  8.74	F1:  8.65
# 	Hypothesis #16 & Reference #3:
# 		metric:	P:  4.76	R:  4.95	F1:  4.85
# 	Hypothesis #17 & Reference #0:
# 		metric:	P:  6.86	R:  6.73	F1:  6.80
# 	Hypothesis #17 & Reference #1:
# 		metric:	P:  6.86	R:  6.86	F1:  6.86
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  1.96	R:  1.92	F1:  1.94
# 	Hypothesis #17 & Reference #3:
# 		metric:	P:  3.92	R:  3.77	F1:  3.85
# 	Hypothesis #18 & Reference #0:
# 		metric:	P:  6.86	R:  6.73	F1:  6.80
# 	Hypothesis #18 & Reference #1:
# 		metric:	P:  5.88	R:  6.06	F1:  5.97
# 	Hypothesis #18 & Reference #2:
# 		metric:	P:  6.86	R:  6.67	F1:  6.76
# 	Hypothesis #18 & Reference #3:
# 		metric:	P:  1.96	R:  1.94	F1:  1.95
# 	Hypothesis #19 & Reference #0:
# 		metric:	P:  3.92	R:  3.96	F1:  3.94
# 	Hypothesis #19 & Reference #1:
# 		metric:	P:  7.84	R:  8.00	F1:  7.92
# 	Hypothesis #19 & Reference #2:
# 		metric:	P:  4.90	R:  4.90	F1:  4.90
# 	Hypothesis #19 & Reference #3:
# 		metric:	P:  5.88	R:  5.83	F1:  5.85
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 10.78	R: 11.70	F1: 11.22
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 11.76	R: 12.00	F1: 11.88
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  1.96	R:  1.98	F1:  1.97
# 	Hypothesis #20 & Reference #3:
# 		metric:	P:  5.88	R:  6.06	F1:  5.97
# 	Hypothesis #21 & Reference #0:
# 		metric:	P:  3.00	R:  3.03	F1:  3.02
# 	Hypothesis #21 & Reference #1:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #21 & Reference #2:
# 		metric:	P:  2.00	R:  1.92	F1:  1.96
# 	Hypothesis #21 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 10.58	R: 10.78	F1: 10.68
# 	Hypothesis #22 & Reference #1:
# 		metric:	P:  4.81	R:  4.95	F1:  4.88
# 	Hypothesis #22 & Reference #2:
# 		metric:	P:  6.73	R:  6.86	F1:  6.80
# 	Hypothesis #22 & Reference #3:
# 		metric:	P:  6.73	R:  7.07	F1:  6.90
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 19.19	R: 18.63	F1: 18.91
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 10.10	R: 10.10	F1: 10.10
# 	Hypothesis #23 & Reference #2:
# 		metric:	P:  9.09	R:  8.57	F1:  8.82
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 17.17	R: 16.83	F1: 17.00
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 10.10	R: 10.10	F1: 10.10
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 13.13	R: 13.13	F1: 13.13
# 	Hypothesis #24 & Reference #2:
# 		metric:	P:  7.07	R:  7.00	F1:  7.04
# 	Hypothesis #24 & Reference #3:
# 		metric:	P:  4.04	R:  3.88	F1:  3.96
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #25 & Reference #1:
# 		metric:	P:  3.00	R:  3.03	F1:  3.02
# 	Hypothesis #25 & Reference #2:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #25 & Reference #3:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #26 & Reference #0:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 13.73	R: 14.89	F1: 14.29
# 	Hypothesis #26 & Reference #2:
# 		metric:	P:  7.84	R:  7.92	F1:  7.88
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 10.78	R: 11.11	F1: 10.95
# 	Hypothesis #27 & Reference #0:
# 		metric:	P:  7.84	R:  7.84	F1:  7.84
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 10.78	R: 10.68	F1: 10.73
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 14.71	R: 14.71	F1: 14.71
# 	Hypothesis #27 & Reference #3:
# 		metric:	P:  6.86	R:  6.86	F1:  6.86
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 14.00	R: 13.73	F1: 13.86
# 	Hypothesis #28 & Reference #1:
# 		metric:	P:  5.00	R:  5.26	F1:  5.13
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 11.00	R: 11.00	F1: 11.00
# 	Hypothesis #28 & Reference #3:
# 		metric:	P:  6.00	R:  5.77	F1:  5.88
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 14.56	R: 14.71	F1: 14.63
# 	Hypothesis #29 & Reference #1:
# 		metric:	P:  8.74	R:  8.91	F1:  8.82
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 14.56	R: 14.85	F1: 14.71
# 	Hypothesis #29 & Reference #3:
# 		metric:	P:  9.71	R: 10.00	F1:  9.85
# 	Hypothesis #30 & Reference #0:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #30 & Reference #1:
# 		metric:	P:  4.95	R:  4.90	F1:  4.93
# 	Hypothesis #30 & Reference #2:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #30 & Reference #3:
# 		metric:	P:  6.93	R:  6.42	F1:  6.67
# 	Hypothesis #31 & Reference #0:
# 		metric:	P:  5.88	R:  5.77	F1:  5.83
# 	Hypothesis #31 & Reference #1:
# 		metric:	P:  3.92	R:  3.92	F1:  3.92
# 	Hypothesis #31 & Reference #2:
# 		metric:	P:  2.94	R:  2.86	F1:  2.90
# 	Hypothesis #31 & Reference #3:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #32 & Reference #0:
# 		metric:	P:  3.00	R:  2.86	F1:  2.93
# 	Hypothesis #32 & Reference #1:
# 		metric:	P:  3.00	R:  2.91	F1:  2.96
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 14.00	R: 13.46	F1: 13.73
# 	Hypothesis #32 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #33 & Reference #0:
# 		metric:	P:  3.77	R:  3.96	F1:  3.86
# 	Hypothesis #33 & Reference #1:
# 		metric:	P:  6.60	R:  7.14	F1:  6.86
# 	Hypothesis #33 & Reference #2:
# 		metric:	P:  4.72	R:  5.00	F1:  4.85
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 10.38	R: 10.58	F1: 10.48
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 10.89	R: 10.89	F1: 10.89
# 	Hypothesis #34 & Reference #1:
# 		metric:	P:  5.94	R:  6.12	F1:  6.03
# 	Hypothesis #34 & Reference #2:
# 		metric:	P:  2.97	R:  2.97	F1:  2.97
# 	Hypothesis #34 & Reference #3:
# 		metric:	P:  0.99	R:  1.00	F1:  1.00
# 	Hypothesis #35 & Reference #0:
# 		metric:	P:  6.48	R:  6.73	F1:  6.60
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 12.04	R: 12.15	F1: 12.09
# 	Hypothesis #35 & Reference #2:
# 		metric:	P:  8.33	R:  8.11	F1:  8.22
# 	Hypothesis #35 & Reference #3:
# 		metric:	P:  3.70	R:  3.92	F1:  3.81
# 	Hypothesis #36 & Reference #0:
# 		metric:	P:  2.91	R:  3.00	F1:  2.96
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  3.88	R:  4.00	F1:  3.94
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  0.97	R:  1.01	F1:  0.99
# 	Hypothesis #36 & Reference #3:
# 		metric:	P:  3.88	R:  3.96	F1:  3.92
# 	Hypothesis #37 & Reference #0:
# 		metric:	P:  8.91	R:  9.00	F1:  8.96
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 17.82	R: 18.00	F1: 17.91
# 	Hypothesis #37 & Reference #2:
# 		metric:	P:  7.92	R:  8.08	F1:  8.00
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 20.79	R: 21.00	F1: 20.90
# 	Hypothesis #38 & Reference #0:
# 		metric:	P:  7.92	R:  7.92	F1:  7.92
# 	Hypothesis #38 & Reference #1:
# 		metric:	P:  7.92	R:  7.84	F1:  7.88
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 10.89	R: 10.78	F1: 10.84
# 	Hypothesis #38 & Reference #3:
# 		metric:	P:  6.93	R:  6.67	F1:  6.80
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 26.47	R: 27.27	F1: 26.87
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 12.75	R: 12.87	F1: 12.81
# 	Hypothesis #39 & Reference #2:
# 		metric:	P:  4.90	R:  5.05	F1:  4.98
# 	Hypothesis #39 & Reference #3:
# 		metric:	P:  5.88	R:  5.77	F1:  5.83
# 	Hypothesis #40 & Reference #0:
# 		metric:	P:  5.94	R:  5.77	F1:  5.85
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 14.85	R: 14.85	F1: 14.85
# 	Hypothesis #40 & Reference #2:
# 		metric:	P:  4.95	R:  4.76	F1:  4.85
# 	Hypothesis #40 & Reference #3:
# 		metric:	P:  1.98	R:  1.96	F1:  1.97
# 	Hypothesis #41 & Reference #0:
# 		metric:	P:  3.81	R:  3.88	F1:  3.85
# 	Hypothesis #41 & Reference #1:
# 		metric:	P:  2.86	R:  2.91	F1:  2.88
# 	Hypothesis #41 & Reference #2:
# 		metric:	P:  2.86	R:  2.91	F1:  2.88
# 	Hypothesis #41 & Reference #3:
# 		metric:	P:  4.76	R:  4.95	F1:  4.85
# 	Hypothesis #42 & Reference #0:
# 		metric:	P:  9.00	R:  8.82	F1:  8.91
# 	Hypothesis #42 & Reference #1:
# 		metric:	P:  7.00	R:  7.07	F1:  7.04
# 	Hypothesis #42 & Reference #2:
# 		metric:	P:  5.00	R:  4.90	F1:  4.95
# 	Hypothesis #42 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #43 & Reference #0:
# 		metric:	P:  7.00	R:  7.07	F1:  7.04
# 	Hypothesis #43 & Reference #1:
# 		metric:	P:  6.00	R:  5.94	F1:  5.97
# 	Hypothesis #43 & Reference #2:
# 		metric:	P:  2.00	R:  2.00	F1:  2.00
# 	Hypothesis #43 & Reference #3:
# 		metric:	P:  7.00	R:  6.73	F1:  6.86
# 	Hypothesis #44 & Reference #0:
# 		metric:	P:  5.00	R:  5.00	F1:  5.00
# 	Hypothesis #44 & Reference #1:
# 		metric:	P:  8.00	R:  8.00	F1:  8.00
# 	Hypothesis #44 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #44 & Reference #3:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  2.94	R:  2.97	F1:  2.96
# 	Hypothesis #45 & Reference #1:
# 		metric:	P:  5.88	R:  5.83	F1:  5.85
# 	Hypothesis #45 & Reference #2:
# 		metric:	P:  8.82	R:  9.00	F1:  8.91
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  1.96	R:  2.00	F1:  1.98
# 	Hypothesis #46 & Reference #0:
# 		metric:	P:  3.96	R:  4.00	F1:  3.98
# 	Hypothesis #46 & Reference #1:
# 		metric:	P:  3.96	R:  3.77	F1:  3.86
# 	Hypothesis #46 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #46 & Reference #3:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #47 & Reference #0:
# 		metric:	P:  4.00	R:  4.04	F1:  4.02
# 	Hypothesis #47 & Reference #1:
# 		metric:	P:  4.00	R:  3.92	F1:  3.96
# 	Hypothesis #47 & Reference #2:
# 		metric:	P:  2.00	R:  2.00	F1:  2.00
# 	Hypothesis #47 & Reference #3:
# 		metric:	P:  5.00	R:  4.95	F1:  4.98
# 	Hypothesis #48 & Reference #0:
# 		metric:	P:  8.74	R:  8.74	F1:  8.74
# 	Hypothesis #48 & Reference #1:
# 		metric:	P:  9.71	R:  9.80	F1:  9.76
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 11.65	R: 11.76	F1: 11.71
# 	Hypothesis #48 & Reference #3:
# 		metric:	P:  4.85	R:  4.81	F1:  4.83
# 	Hypothesis #49 & Reference #0:
# 		metric:	P:  3.88	R:  3.81	F1:  3.85
# 	Hypothesis #49 & Reference #1:
# 		metric:	P:  6.80	R:  6.86	F1:  6.83
# 	Hypothesis #49 & Reference #2:
# 		metric:	P:  0.97	R:  0.99	F1:  0.98
# 	Hypothesis #49 & Reference #3:
# 		metric:	P:  3.88	R:  3.96	F1:  3.92
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P:  4.90	R:  4.90	F1:  4.90
# 	Hypothesis #0 & Reference #1:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #0 & Reference #2:
# 		metric:	P:  4.90	R:  5.10	F1:  5.00
# 	Hypothesis #0 & Reference #3:
# 		metric:	P:  3.92	R:  4.04	F1:  3.98
# 	Hypothesis #1 & Reference #0:
# 		metric:	P:  1.03	R:  0.95	F1:  0.99
# 	Hypothesis #1 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #1 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #1 & Reference #3:
# 		metric:	P:  3.09	R:  2.91	F1:  3.00
# 	Hypothesis #2 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #2 & Reference #1:
# 		metric:	P:  2.02	R:  2.00	F1:  2.01
# 	Hypothesis #2 & Reference #2:
# 		metric:	P:  4.04	R:  4.00	F1:  4.02
# 	Hypothesis #2 & Reference #3:
# 		metric:	P:  1.01	R:  1.05	F1:  1.03
# 	Hypothesis #3 & Reference #0:
# 		metric:	P:  0.98	R:  0.97	F1:  0.98
# 	Hypothesis #3 & Reference #1:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #3 & Reference #2:
# 		metric:	P:  0.98	R:  1.00	F1:  0.99
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  0.98	R:  0.99	F1:  0.99
# 	Hypothesis #4 & Reference #0:
# 		metric:	P:  1.00	R:  1.02	F1:  1.01
# 	Hypothesis #4 & Reference #1:
# 		metric:	P:  5.00	R:  5.10	F1:  5.05
# 	Hypothesis #4 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #4 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #5 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #5 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #5 & Reference #2:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #6 & Reference #0:
# 		metric:	P:  2.80	R:  2.94	F1:  2.87
# 	Hypothesis #6 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #6 & Reference #2:
# 		metric:	P:  3.74	R:  4.04	F1:  3.88
# 	Hypothesis #6 & Reference #3:
# 		metric:	P:  0.93	R:  0.98	F1:  0.96
# 	Hypothesis #7 & Reference #0:
# 		metric:	P:  0.98	R:  1.04	F1:  1.01
# 	Hypothesis #7 & Reference #1:
# 		metric:	P:  3.92	R:  4.12	F1:  4.02
# 	Hypothesis #7 & Reference #2:
# 		metric:	P:  1.96	R:  2.04	F1:  2.00
# 	Hypothesis #7 & Reference #3:
# 		metric:	P:  2.94	R:  3.09	F1:  3.02
# 	Hypothesis #8 & Reference #0:
# 		metric:	P:  2.00	R:  2.06	F1:  2.03
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #8 & Reference #2:
# 		metric:	P:  1.00	R:  1.00	F1:  1.00
# 	Hypothesis #8 & Reference #3:
# 		metric:	P:  2.00	R:  1.98	F1:  1.99
# 	Hypothesis #9 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #9 & Reference #1:
# 		metric:	P:  1.02	R:  1.02	F1:  1.02
# 	Hypothesis #9 & Reference #2:
# 		metric:	P:  8.16	R:  7.77	F1:  7.96
# 	Hypothesis #9 & Reference #3:
# 		metric:	P:  2.04	R:  1.98	F1:  2.01
# 	Hypothesis #10 & Reference #0:
# 		metric:	P:  8.74	R:  8.91	F1:  8.82
# 	Hypothesis #10 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #10 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #10 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #0:
# 		metric:	P:  2.00	R:  1.98	F1:  1.99
# 	Hypothesis #11 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #11 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #12 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 12.75	R: 13.00	F1: 12.87
# 	Hypothesis #12 & Reference #2:
# 		metric:	P:  2.94	R:  3.03	F1:  2.99
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #13 & Reference #0:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #13 & Reference #1:
# 		metric:	P:  1.01	R:  1.00	F1:  1.01
# 	Hypothesis #13 & Reference #2:
# 		metric:	P:  1.01	R:  1.06	F1:  1.04
# 	Hypothesis #13 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #14 & Reference #0:
# 		metric:	P:  0.96	R:  1.02	F1:  0.99
# 	Hypothesis #14 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #14 & Reference #2:
# 		metric:	P:  1.92	R:  2.00	F1:  1.96
# 	Hypothesis #14 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #16 & Reference #0:
# 		metric:	P:  1.92	R:  1.98	F1:  1.95
# 	Hypothesis #16 & Reference #1:
# 		metric:	P:  5.77	R:  6.06	F1:  5.91
# 	Hypothesis #16 & Reference #2:
# 		metric:	P:  2.88	R:  2.94	F1:  2.91
# 	Hypothesis #16 & Reference #3:
# 		metric:	P:  0.96	R:  1.00	F1:  0.98
# 	Hypothesis #17 & Reference #0:
# 		metric:	P:  3.96	R:  3.88	F1:  3.92
# 	Hypothesis #17 & Reference #1:
# 		metric:	P:  3.96	R:  3.96	F1:  3.96
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #17 & Reference #3:
# 		metric:	P:  0.99	R:  0.95	F1:  0.97
# 	Hypothesis #18 & Reference #0:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #18 & Reference #1:
# 		metric:	P:  0.99	R:  1.02	F1:  1.01
# 	Hypothesis #18 & Reference #2:
# 		metric:	P:  0.99	R:  0.96	F1:  0.98
# 	Hypothesis #18 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #1:
# 		metric:	P:  1.98	R:  2.02	F1:  2.00
# 	Hypothesis #19 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #19 & Reference #3:
# 		metric:	P:  0.99	R:  0.98	F1:  0.99
# 	Hypothesis #20 & Reference #0:
# 		metric:	P:  2.97	R:  3.23	F1:  3.09
# 	Hypothesis #20 & Reference #1:
# 		metric:	P:  4.95	R:  5.05	F1:  5.00
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #20 & Reference #3:
# 		metric:	P:  2.97	R:  3.06	F1:  3.02
# 	Hypothesis #21 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #21 & Reference #1:
# 		metric:	P:  2.02	R:  2.00	F1:  2.01
# 	Hypothesis #21 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #21 & Reference #3:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #22 & Reference #0:
# 		metric:	P:  1.94	R:  1.98	F1:  1.96
# 	Hypothesis #22 & Reference #1:
# 		metric:	P:  0.97	R:  1.00	F1:  0.99
# 	Hypothesis #22 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #22 & Reference #3:
# 		metric:	P:  1.94	R:  2.04	F1:  1.99
# 	Hypothesis #23 & Reference #0:
# 		metric:	P:  9.18	R:  8.91	F1:  9.05
# 	Hypothesis #23 & Reference #1:
# 		metric:	P:  6.12	R:  6.12	F1:  6.12
# 	Hypothesis #23 & Reference #2:
# 		metric:	P:  4.08	R:  3.85	F1:  3.96
# 	Hypothesis #23 & Reference #3:
# 		metric:	P:  7.14	R:  7.00	F1:  7.07
# 	Hypothesis #24 & Reference #0:
# 		metric:	P:  1.02	R:  1.02	F1:  1.02
# 	Hypothesis #24 & Reference #1:
# 		metric:	P:  9.18	R:  9.18	F1:  9.18
# 	Hypothesis #24 & Reference #2:
# 		metric:	P:  1.02	R:  1.01	F1:  1.02
# 	Hypothesis #24 & Reference #3:
# 		metric:	P:  1.02	R:  0.98	F1:  1.00
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #25 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #25 & Reference #2:
# 		metric:	P:  1.01	R:  1.01	F1:  1.01
# 	Hypothesis #25 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #26 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #26 & Reference #1:
# 		metric:	P:  7.92	R:  8.60	F1:  8.25
# 	Hypothesis #26 & Reference #2:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #26 & Reference #3:
# 		metric:	P:  3.96	R:  4.08	F1:  4.02
# 	Hypothesis #27 & Reference #0:
# 		metric:	P:  1.98	R:  1.98	F1:  1.98
# 	Hypothesis #27 & Reference #1:
# 		metric:	P:  6.93	R:  6.86	F1:  6.90
# 	Hypothesis #27 & Reference #2:
# 		metric:	P:  7.92	R:  7.92	F1:  7.92
# 	Hypothesis #27 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 10.10	R:  9.90	F1: 10.00
# 	Hypothesis #28 & Reference #1:
# 		metric:	P:  1.01	R:  1.06	F1:  1.04
# 	Hypothesis #28 & Reference #2:
# 		metric:	P:  4.04	R:  4.04	F1:  4.04
# 	Hypothesis #28 & Reference #3:
# 		metric:	P:  1.01	R:  0.97	F1:  0.99
# 	Hypothesis #29 & Reference #0:
# 		metric:	P:  5.88	R:  5.94	F1:  5.91
# 	Hypothesis #29 & Reference #1:
# 		metric:	P:  1.96	R:  2.00	F1:  1.98
# 	Hypothesis #29 & Reference #2:
# 		metric:	P:  6.86	R:  7.00	F1:  6.93
# 	Hypothesis #29 & Reference #3:
# 		metric:	P:  1.96	R:  2.02	F1:  1.99
# 	Hypothesis #30 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #30 & Reference #3:
# 		metric:	P:  1.00	R:  0.93	F1:  0.96
# 	Hypothesis #31 & Reference #0:
# 		metric:	P:  0.99	R:  0.97	F1:  0.98
# 	Hypothesis #31 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #31 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #31 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #32 & Reference #2:
# 		metric:	P:  8.08	R:  7.77	F1:  7.92
# 	Hypothesis #32 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #33 & Reference #0:
# 		metric:	P:  0.95	R:  1.00	F1:  0.98
# 	Hypothesis #33 & Reference #1:
# 		metric:	P:  1.90	R:  2.06	F1:  1.98
# 	Hypothesis #33 & Reference #2:
# 		metric:	P:  1.90	R:  2.02	F1:  1.96
# 	Hypothesis #33 & Reference #3:
# 		metric:	P:  6.67	R:  6.80	F1:  6.73
# 	Hypothesis #34 & Reference #0:
# 		metric:	P:  4.00	R:  4.00	F1:  4.00
# 	Hypothesis #34 & Reference #1:
# 		metric:	P:  1.00	R:  1.03	F1:  1.02
# 	Hypothesis #34 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #34 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #35 & Reference #0:
# 		metric:	P:  1.87	R:  1.94	F1:  1.90
# 	Hypothesis #35 & Reference #1:
# 		metric:	P:  5.61	R:  5.66	F1:  5.63
# 	Hypothesis #35 & Reference #2:
# 		metric:	P:  2.80	R:  2.73	F1:  2.76
# 	Hypothesis #35 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  0.98	R:  1.01	F1:  1.00
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #36 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #37 & Reference #0:
# 		metric:	P:  4.00	R:  4.04	F1:  4.02
# 	Hypothesis #37 & Reference #1:
# 		metric:	P:  8.00	R:  8.08	F1:  8.04
# 	Hypothesis #37 & Reference #2:
# 		metric:	P:  2.00	R:  2.04	F1:  2.02
# 	Hypothesis #37 & Reference #3:
# 		metric:	P:  8.00	R:  8.08	F1:  8.04
# 	Hypothesis #38 & Reference #0:
# 		metric:	P:  3.00	R:  3.00	F1:  3.00
# 	Hypothesis #38 & Reference #1:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #38 & Reference #2:
# 		metric:	P:  3.00	R:  2.97	F1:  2.99
# 	Hypothesis #38 & Reference #3:
# 		metric:	P:  2.00	R:  1.92	F1:  1.96
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 12.87	R: 13.27	F1: 13.07
# 	Hypothesis #39 & Reference #1:
# 		metric:	P:  6.93	R:  7.00	F1:  6.97
# 	Hypothesis #39 & Reference #2:
# 		metric:	P:  0.99	R:  1.02	F1:  1.01
# 	Hypothesis #39 & Reference #3:
# 		metric:	P:  1.98	R:  1.94	F1:  1.96
# 	Hypothesis #40 & Reference #0:
# 		metric:	P:  1.00	R:  0.97	F1:  0.99
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 12.00	R: 12.00	F1: 12.00
# 	Hypothesis #40 & Reference #2:
# 		metric:	P:  1.00	R:  0.96	F1:  0.98
# 	Hypothesis #40 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #1:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #41 & Reference #2:
# 		metric:	P:  0.96	R:  0.98	F1:  0.97
# 	Hypothesis #41 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #42 & Reference #0:
# 		metric:	P:  3.03	R:  2.97	F1:  3.00
# 	Hypothesis #42 & Reference #1:
# 		metric:	P:  1.01	R:  1.02	F1:  1.02
# 	Hypothesis #42 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #42 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #43 & Reference #0:
# 		metric:	P:  3.03	R:  3.06	F1:  3.05
# 	Hypothesis #43 & Reference #1:
# 		metric:	P:  3.03	R:  3.00	F1:  3.02
# 	Hypothesis #43 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #43 & Reference #3:
# 		metric:	P:  1.01	R:  0.97	F1:  0.99
# 	Hypothesis #44 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #44 & Reference #1:
# 		metric:	P:  2.02	R:  2.02	F1:  2.02
# 	Hypothesis #44 & Reference #2:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #44 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  1.98	R:  2.00	F1:  1.99
# 	Hypothesis #45 & Reference #1:
# 		metric:	P:  2.97	R:  2.94	F1:  2.96
# 	Hypothesis #45 & Reference #2:
# 		metric:	P:  4.95	R:  5.05	F1:  5.00
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# 	Hypothesis #46 & Reference #0:
# 		metric:	P:  0.00	R:  0.00	F1:  0.00
# ...
# 		metric:	P: 23.76	R: 23.76	F1: 23.76
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 24.85	R: 24.06	F1: 24.45
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 29.14	R: 29.14	F1: 29.14
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 27.01	R: 27.01	F1: 27.01
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 29.14	R: 29.14	F1: 29.14
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 27.01	R: 27.01	F1: 27.01
# 	Hypothesis #45 & Reference #0:
# 		metric:	P: 18.96	R: 19.11	F1: 19.03
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 23.37	R: 23.18	F1: 23.28
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 30.73	R: 31.24	F1: 30.98
# 	Hypothesis #45 & Reference #3:
# 		metric:	P: 17.82	R: 18.11	F1: 17.97
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 25.73	R: 25.94	F1: 25.83
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 25.73	R: 24.72	F1: 25.21
# 	Hypothesis #46 & Reference #2:
# 		metric:	P: 20.24	R: 19.92	F1: 20.08
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 28.90	R: 29.14	F1: 29.02
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 23.76	R: 23.95	F1: 23.86
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 28.08	R: 27.63	F1: 27.85
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 23.76	R: 23.76	F1: 23.76
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 24.85	R: 24.65	F1: 24.75
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 31.50	R: 31.50	F1: 31.50
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 33.50	R: 33.78	F1: 33.64
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 31.50	R: 31.75	F1: 31.62
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 27.40	R: 27.19	F1: 27.30
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 24.25	R: 23.87	F1: 24.06
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 24.25	R: 24.45	F1: 24.35
# 	Hypothesis #49 & Reference #2:
# 		metric:	P: 18.80	R: 19.11	F1: 18.96
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 24.25	R: 24.65	F1: 24.45
#
# 	Hypothesis #0 & Reference #0:
# 		metric:	P: 17.80	R:  7.03	F1: 10.08
# 	Hypothesis #0 & Reference #1:
# 		metric:	P: 15.95	R:  6.45	F1:  9.18
# 	Hypothesis #0 & Reference #2:
# 		metric:	P: 18.35	R:  7.60	F1: 10.75
# 	Hypothesis #0 & Reference #3:
# 		metric:	P: 17.07	R:  6.98	F1:  9.91
# 	Hypothesis #1 & Reference #0:
# 		metric:	P: 12.30	R:  4.47	F1:  6.56
# 	Hypothesis #1 & Reference #1:
# 		metric:	P: 11.56	R:  4.25	F1:  6.21
# 	Hypothesis #1 & Reference #2:
# 		metric:	P: 11.91	R:  4.53	F1:  6.56
# 	Hypothesis #1 & Reference #3:
# 		metric:	P: 14.18	R:  5.27	F1:  7.68
# 	Hypothesis #2 & Reference #0:
# 		metric:	P: 13.40	R:  5.26	F1:  7.55
# 	Hypothesis #2 & Reference #1:
# 		metric:	P: 13.62	R:  5.35	F1:  7.68
# 	Hypothesis #2 & Reference #2:
# 		metric:	P: 16.36	R:  6.42	F1:  9.22
# 	Hypothesis #2 & Reference #3:
# 		metric:	P: 13.83	R:  5.77	F1:  8.14
# 	Hypothesis #3 & Reference #0:
# 		metric:	P: 12.67	R:  4.95	F1:  7.12
# 	Hypothesis #3 & Reference #1:
# 		metric:	P: 11.48	R:  4.64	F1:  6.61
# 	Hypothesis #3 & Reference #2:
# 		metric:	P: 11.42	R:  4.62	F1:  6.58
# 	Hypothesis #3 & Reference #3:
# 		metric:	P:  9.49	R:  3.79	F1:  5.42
# 	Hypothesis #4 & Reference #0:
# 		metric:	P: 10.14	R:  4.12	F1:  5.85
# 	Hypothesis #4 & Reference #1:
# 		metric:	P: 18.01	R:  7.31	F1: 10.40
# 	Hypothesis #4 & Reference #2:
# 		metric:	P: 11.49	R:  4.56	F1:  6.52
# 	Hypothesis #4 & Reference #3:
# 		metric:	P: 11.72	R:  4.59	F1:  6.60
# 	Hypothesis #5 & Reference #0:
# 		metric:	P: 15.38	R:  6.04	F1:  8.67
# 	Hypothesis #5 & Reference #1:
# 		metric:	P: 10.60	R:  4.31	F1:  6.13
# 	Hypothesis #5 & Reference #2:
# 		metric:	P: 13.47	R:  5.35	F1:  7.66
# 	Hypothesis #5 & Reference #3:
# 		metric:	P:  9.40	R:  3.69	F1:  5.30
# 	Hypothesis #6 & Reference #0:
# 		metric:	P: 13.07	R:  5.41	F1:  7.65
# 	Hypothesis #6 & Reference #1:
# 		metric:	P: 12.34	R:  5.29	F1:  7.41
# 	Hypothesis #6 & Reference #2:
# 		metric:	P: 19.18	R:  8.23	F1: 11.51
# 	Hypothesis #6 & Reference #3:
# 		metric:	P: 12.93	R:  5.35	F1:  7.57
# 	Hypothesis #7 & Reference #0:
# 		metric:	P: 12.66	R:  5.37	F1:  7.54
# 	Hypothesis #7 & Reference #1:
# 		metric:	P: 15.26	R:  6.40	F1:  9.01
# 	Hypothesis #7 & Reference #2:
# 		metric:	P: 12.88	R:  5.33	F1:  7.54
# 	Hypothesis #7 & Reference #3:
# 		metric:	P: 12.04	R:  5.04	F1:  7.11
# 	Hypothesis #8 & Reference #0:
# 		metric:	P: 12.99	R:  5.34	F1:  7.57
# 	Hypothesis #8 & Reference #1:
# 		metric:	P:  9.15	R:  3.55	F1:  5.11
# 	Hypothesis #8 & Reference #2:
# 		metric:	P: 12.21	R:  4.84	F1:  6.93
# 	Hypothesis #8 & Reference #3:
# 		metric:	P: 14.08	R:  5.52	F1:  7.93
# 	Hypothesis #9 & Reference #0:
# 		metric:	P: 11.21	R:  4.31	F1:  6.22
# 	Hypothesis #9 & Reference #1:
# 		metric:	P: 11.59	R:  4.62	F1:  6.60
# 	Hypothesis #9 & Reference #2:
# 		metric:	P: 18.18	R:  6.83	F1:  9.92
# 	Hypothesis #9 & Reference #3:
# 		metric:	P: 12.91	R:  4.96	F1:  7.17
# 	Hypothesis #10 & Reference #0:
# 		metric:	P: 17.12	R:  6.91	F1:  9.84
# 	Hypothesis #10 & Reference #1:
# 		metric:	P: 11.51	R:  4.70	F1:  6.67
# 	Hypothesis #10 & Reference #2:
# 		metric:	P: 11.59	R:  4.68	F1:  6.67
# 	Hypothesis #10 & Reference #3:
# 		metric:	P: 12.88	R:  5.38	F1:  7.59
# 	Hypothesis #11 & Reference #0:
# 		metric:	P: 14.18	R:  5.56	F1:  7.98
# 	Hypothesis #11 & Reference #1:
# 		metric:	P: 15.25	R:  6.19	F1:  8.81
# 	Hypothesis #11 & Reference #2:
# 		metric:	P:  9.38	R:  3.63	F1:  5.24
# 	Hypothesis #11 & Reference #3:
# 		metric:	P: 12.07	R:  4.67	F1:  6.74
# 	Hypothesis #12 & Reference #0:
# 		metric:	P: 13.48	R:  5.51	F1:  7.83
# 	Hypothesis #12 & Reference #1:
# 		metric:	P: 19.45	R:  7.87	F1: 11.20
# 	Hypothesis #12 & Reference #2:
# 		metric:	P: 11.34	R:  4.64	F1:  6.58
# 	Hypothesis #12 & Reference #3:
# 		metric:	P:  8.32	R:  3.33	F1:  4.75
# 	Hypothesis #13 & Reference #0:
# 		metric:	P: 14.92	R:  5.86	F1:  8.41
# 	Hypothesis #13 & Reference #1:
# 		metric:	P: 14.36	R:  5.64	F1:  8.10
# 	Hypothesis #13 & Reference #2:
# 		metric:	P: 10.51	R:  4.44	F1:  6.24
# 	Hypothesis #13 & Reference #3:
# 		metric:	P: 12.32	R:  4.72	F1:  6.83
# 	Hypothesis #14 & Reference #0:
# 		metric:	P: 11.47	R:  4.84	F1:  6.81
# 	Hypothesis #14 & Reference #1:
# 		metric:	P: 11.61	R:  5.21	F1:  7.19
# 	Hypothesis #14 & Reference #2:
# 		metric:	P: 13.96	R:  5.75	F1:  8.15
# 	Hypothesis #14 & Reference #3:
# 		metric:	P: 10.79	R:  4.45	F1:  6.30
# 	Hypothesis #15 & Reference #0:
# 		metric:	P:  8.34	R:  3.84	F1:  5.26
# 	Hypothesis #15 & Reference #1:
# 		metric:	P: 10.38	R:  4.54	F1:  6.32
# 	Hypothesis #15 & Reference #2:
# 		metric:	P:  6.19	R:  2.75	F1:  3.80
# 	Hypothesis #15 & Reference #3:
# 		metric:	P:  8.49	R:  3.63	F1:  5.08
# 	Hypothesis #16 & Reference #0:
# 		metric:	P: 11.55	R:  4.70	F1:  6.68
# 	Hypothesis #16 & Reference #1:
# 		metric:	P: 17.02	R:  7.10	F1: 10.02
# 	Hypothesis #16 & Reference #2:
# 		metric:	P: 14.01	R:  5.64	F1:  8.04
# 	Hypothesis #16 & Reference #3:
# 		metric:	P: 11.82	R:  4.87	F1:  6.90
# 	Hypothesis #17 & Reference #0:
# 		metric:	P: 12.24	R:  4.73	F1:  6.83
# 	Hypothesis #17 & Reference #1:
# 		metric:	P: 11.99	R:  4.75	F1:  6.80
# 	Hypothesis #17 & Reference #2:
# 		metric:	P:  9.65	R:  3.73	F1:  5.38
# 	Hypothesis #17 & Reference #3:
# 		metric:	P: 11.73	R:  4.43	F1:  6.44
# 	Hypothesis #18 & Reference #0:
# 		metric:	P: 15.10	R:  5.84	F1:  8.42
# 	Hypothesis #18 & Reference #1:
# 		metric:	P: 12.09	R:  4.96	F1:  7.03
# 	Hypothesis #18 & Reference #2:
# 		metric:	P: 14.02	R:  5.36	F1:  7.76
# 	Hypothesis #18 & Reference #3:
# 		metric:	P: 12.09	R:  4.73	F1:  6.80
# 	Hypothesis #19 & Reference #0:
# 		metric:	P: 11.53	R:  4.62	F1:  6.60
# 	Hypothesis #19 & Reference #1:
# 		metric:	P: 13.68	R:  5.54	F1:  7.89
# 	Hypothesis #19 & Reference #2:
# 		metric:	P: 11.75	R:  4.65	F1:  6.66
# 	Hypothesis #19 & Reference #3:
# 		metric:	P: 13.42	R:  5.25	F1:  7.55
# 	Hypothesis #20 & Reference #0:
# 		metric:	P: 13.50	R:  5.89	F1:  8.20
# 	Hypothesis #20 & Reference #1:
# 		metric:	P: 16.49	R:  6.68	F1:  9.51
# 	Hypothesis #20 & Reference #2:
# 		metric:	P:  9.06	R:  3.63	F1:  5.18
# 	Hypothesis #20 & Reference #3:
# 		metric:	P: 13.34	R:  5.47	F1:  7.76
# 	Hypothesis #21 & Reference #0:
# 		metric:	P: 11.68	R:  4.70	F1:  6.70
# 	Hypothesis #21 & Reference #1:
# 		metric:	P: 13.33	R:  5.23	F1:  7.51
# 	Hypothesis #21 & Reference #2:
# 		metric:	P: 11.68	R:  4.43	F1:  6.42
# 	Hypothesis #21 & Reference #3:
# 		metric:	P: 11.18	R:  4.44	F1:  6.36
# 	Hypothesis #22 & Reference #0:
# 		metric:	P: 17.67	R:  7.13	F1: 10.16
# 	Hypothesis #22 & Reference #1:
# 		metric:	P: 15.26	R:  6.23	F1:  8.85
# 	Hypothesis #22 & Reference #2:
# 		metric:	P: 15.36	R:  6.20	F1:  8.83
# 	Hypothesis #22 & Reference #3:
# 		metric:	P: 16.33	R:  6.83	F1:  9.63
# 	Hypothesis #23 & Reference #0:
# 		metric:	P: 20.21	R:  7.77	F1: 11.22
# 	Hypothesis #23 & Reference #1:
# 		metric:	P: 16.92	R:  6.74	F1:  9.64
# 	Hypothesis #23 & Reference #2:
# 		metric:	P: 18.08	R:  6.71	F1:  9.79
# 	Hypothesis #23 & Reference #3:
# 		metric:	P: 20.14	R:  7.83	F1: 11.27
# 	Hypothesis #24 & Reference #0:
# 		metric:	P: 17.23	R:  6.86	F1:  9.81
# 	Hypothesis #24 & Reference #1:
# 		metric:	P: 18.85	R:  7.51	F1: 10.74
# 	Hypothesis #24 & Reference #2:
# 		metric:	P: 13.10	R:  5.15	F1:  7.39
# 	Hypothesis #24 & Reference #3:
# 		metric:	P: 13.80	R:  5.24	F1:  7.60
# 	Hypothesis #25 & Reference #0:
# 		metric:	P:  9.92	R:  3.94	F1:  5.64
# 	Hypothesis #25 & Reference #1:
# 		metric:	P: 11.97	R:  4.81	F1:  6.86
# 	Hypothesis #25 & Reference #2:
# 		metric:	P: 12.33	R:  4.90	F1:  7.01
# 	Hypothesis #25 & Reference #3:
# 		metric:	P: 10.44	R:  4.15	F1:  5.94
# 	Hypothesis #26 & Reference #0:
# 		metric:	P: 12.21	R:  4.89	F1:  6.98
# 	Hypothesis #26 & Reference #1:
# 		metric:	P: 19.53	R:  8.51	F1: 11.86
# 	Hypothesis #26 & Reference #2:
# 		metric:	P: 17.53	R:  7.02	F1: 10.02
# 	Hypothesis #26 & Reference #3:
# 		metric:	P: 17.78	R:  7.29	F1: 10.34
# 	Hypothesis #27 & Reference #0:
# 		metric:	P: 21.02	R:  8.32	F1: 11.92
# 	Hypothesis #27 & Reference #1:
# 		metric:	P: 22.24	R:  8.70	F1: 12.51
# 	Hypothesis #27 & Reference #2:
# 		metric:	P: 23.81	R:  9.42	F1: 13.50
# 	Hypothesis #27 & Reference #3:
# 		metric:	P: 15.76	R:  6.24	F1:  8.94
# 	Hypothesis #28 & Reference #0:
# 		metric:	P: 19.63	R:  7.62	F1: 10.98
# 	Hypothesis #28 & Reference #1:
# 		metric:	P: 10.81	R:  4.56	F1:  6.42
# 	Hypothesis #28 & Reference #2:
# 		metric:	P: 15.39	R:  6.12	F1:  8.75
# 	Hypothesis #28 & Reference #3:
# 		metric:	P: 13.88	R:  5.26	F1:  7.63
# 	Hypothesis #29 & Reference #0:
# 		metric:	P: 22.05	R:  8.81	F1: 12.59
# 	Hypothesis #29 & Reference #1:
# 		metric:	P: 14.76	R:  5.97	F1:  8.50
# 	Hypothesis #29 & Reference #2:
# 		metric:	P: 14.76	R:  5.97	F1:  8.50
# 	Hypothesis #29 & Reference #3:
# 		metric:	P: 17.69	R:  7.24	F1: 10.27
# 	Hypothesis #30 & Reference #0:
# 		metric:	P: 13.19	R:  5.11	F1:  7.37
# 	Hypothesis #30 & Reference #1:
# 		metric:	P: 17.61	R:  6.90	F1:  9.92
# 	Hypothesis #30 & Reference #2:
# 		metric:	P: 13.80	R:  5.35	F1:  7.71
# 	Hypothesis #30 & Reference #3:
# 		metric:	P: 15.24	R:  5.52	F1:  8.10
# 	Hypothesis #31 & Reference #0:
# 		metric:	P: 13.47	R:  5.21	F1:  7.51
# 	Hypothesis #31 & Reference #1:
# 		metric:	P: 12.51	R:  4.95	F1:  7.10
# 	Hypothesis #31 & Reference #2:
# 		metric:	P: 12.07	R:  4.61	F1:  6.68
# 	Hypothesis #31 & Reference #3:
# 		metric:	P: 11.08	R:  4.44	F1:  6.34
# 	Hypothesis #32 & Reference #0:
# 		metric:	P: 13.93	R:  5.22	F1:  7.60
# 	Hypothesis #32 & Reference #1:
# 		metric:	P: 14.38	R:  5.52	F1:  7.97
# 	Hypothesis #32 & Reference #2:
# 		metric:	P: 19.82	R:  7.52	F1: 10.90
# 	Hypothesis #32 & Reference #3:
# 		metric:	P: 11.61	R:  4.61	F1:  6.60
# 	Hypothesis #33 & Reference #0:
# 		metric:	P: 10.55	R:  4.39	F1:  6.20
# 	Hypothesis #33 & Reference #1:
# 		metric:	P: 13.96	R:  6.02	F1:  8.41
# 	Hypothesis #33 & Reference #2:
# 		metric:	P: 11.35	R:  4.78	F1:  6.73
# 	Hypothesis #33 & Reference #3:
# 		metric:	P: 14.97	R:  6.01	F1:  8.58
# 	Hypothesis #34 & Reference #0:
# 		metric:	P: 16.40	R:  6.50	F1:  9.31
# 	Hypothesis #34 & Reference #1:
# 		metric:	P: 12.92	R:  5.31	F1:  7.53
# 	Hypothesis #34 & Reference #2:
# 		metric:	P: 13.12	R:  5.20	F1:  7.45
# 	Hypothesis #34 & Reference #3:
# 		metric:	P: 11.20	R:  4.49	F1:  6.41
# 	Hypothesis #35 & Reference #0:
# 		metric:	P: 14.72	R:  6.03	F1:  8.55
# 	Hypothesis #35 & Reference #1:
# 		metric:	P: 18.83	R:  7.45	F1: 10.68
# 	Hypothesis #35 & Reference #2:
# 		metric:	P: 14.90	R:  5.65	F1:  8.19
# 	Hypothesis #35 & Reference #3:
# 		metric:	P: 12.41	R:  5.20	F1:  7.33
# 	Hypothesis #36 & Reference #0:
# 		metric:	P: 13.70	R:  5.60	F1:  7.95
# 	Hypothesis #36 & Reference #1:
# 		metric:	P:  9.44	R:  3.86	F1:  5.48
# 	Hypothesis #36 & Reference #2:
# 		metric:	P:  9.20	R:  3.81	F1:  5.39
# 	Hypothesis #36 & Reference #3:
# 		metric:	P: 11.76	R:  4.76	F1:  6.77
# 	Hypothesis #37 & Reference #0:
# 		metric:	P: 16.71	R:  6.71	F1:  9.57
# 	Hypothesis #37 & Reference #1:
# 		metric:	P: 22.87	R:  9.18	F1: 13.10
# 	Hypothesis #37 & Reference #2:
# 		metric:	P: 15.17	R:  6.16	F1:  8.76
# 	Hypothesis #37 & Reference #3:
# 		metric:	P: 19.53	R:  7.83	F1: 11.18
# 	Hypothesis #38 & Reference #0:
# 		metric:	P: 12.51	R:  4.96	F1:  7.10
# 	Hypothesis #38 & Reference #1:
# 		metric:	P: 14.29	R:  5.60	F1:  8.05
# 	Hypothesis #38 & Reference #2:
# 		metric:	P: 14.54	R:  5.70	F1:  8.19
# 	Hypothesis #38 & Reference #3:
# 		metric:	P: 12.69	R:  4.81	F1:  6.97
# 	Hypothesis #39 & Reference #0:
# 		metric:	P: 31.68	R: 12.99	F1: 18.42
# 	Hypothesis #39 & Reference #1:
# 		metric:	P: 20.80	R:  8.33	F1: 11.90
# 	Hypothesis #39 & Reference #2:
# 		metric:	P: 13.54	R:  5.55	F1:  7.88
# 	Hypothesis #39 & Reference #3:
# 		metric:	P: 14.21	R:  5.49	F1:  7.92
# 	Hypothesis #40 & Reference #0:
# 		metric:	P: 16.34	R:  6.26	F1:  9.05
# 	Hypothesis #40 & Reference #1:
# 		metric:	P: 20.11	R:  7.98	F1: 11.42
# 	Hypothesis #40 & Reference #2:
# 		metric:	P: 14.24	R:  5.39	F1:  7.82
# 	Hypothesis #40 & Reference #3:
# 		metric:	P: 12.20	R:  4.78	F1:  6.87
# 	Hypothesis #41 & Reference #0:
# 		metric:	P: 15.20	R:  6.12	F1:  8.72
# 	Hypothesis #41 & Reference #1:
# 		metric:	P: 11.74	R:  4.72	F1:  6.74
# 	Hypothesis #41 & Reference #2:
# 		metric:	P: 11.58	R:  4.66	F1:  6.65
# 	Hypothesis #41 & Reference #3:
# 		metric:	P: 11.39	R:  4.69	F1:  6.65
# 	Hypothesis #42 & Reference #0:
# 		metric:	P: 13.95	R:  5.41	F1:  7.80
# 	Hypothesis #42 & Reference #1:
# 		metric:	P: 16.49	R:  6.63	F1:  9.46
# 	Hypothesis #42 & Reference #2:
# 		metric:	P: 15.83	R:  6.14	F1:  8.85
# 	Hypothesis #42 & Reference #3:
# 		metric:	P: 14.71	R:  5.85	F1:  8.37
# 	Hypothesis #43 & Reference #0:
# 		metric:	P: 14.17	R:  5.70	F1:  8.13
# 	Hypothesis #43 & Reference #1:
# 		metric:	P: 14.44	R:  5.67	F1:  8.14
# 	Hypothesis #43 & Reference #2:
# 		metric:	P: 11.61	R:  4.61	F1:  6.60
# 	Hypothesis #43 & Reference #3:
# 		metric:	P: 12.33	R:  4.68	F1:  6.78
# 	Hypothesis #44 & Reference #0:
# 		metric:	P: 14.64	R:  5.81	F1:  8.32
# 	Hypothesis #44 & Reference #1:
# 		metric:	P: 14.10	R:  5.60	F1:  8.02
# 	Hypothesis #44 & Reference #2:
# 		metric:	P: 13.94	R:  5.54	F1:  7.93
# 	Hypothesis #44 & Reference #3:
# 		metric:	P: 13.18	R:  5.24	F1:  7.49
# 	Hypothesis #45 & Reference #0:
# 		metric:	P:  9.42	R:  3.77	F1:  5.38
# 	Hypothesis #45 & Reference #1:
# 		metric:	P: 12.69	R:  4.97	F1:  7.14
# 	Hypothesis #45 & Reference #2:
# 		metric:	P: 17.35	R:  7.03	F1: 10.00
# 	Hypothesis #45 & Reference #3:
# 		metric:	P:  9.28	R:  3.76	F1:  5.35
# 	Hypothesis #46 & Reference #0:
# 		metric:	P: 12.49	R:  5.01	F1:  7.15
# 	Hypothesis #46 & Reference #1:
# 		metric:	P: 13.27	R:  4.97	F1:  7.23
# 	Hypothesis #46 & Reference #2:
# 		metric:	P:  9.67	R:  3.75	F1:  5.40
# 	Hypothesis #46 & Reference #3:
# 		metric:	P: 14.23	R:  5.71	F1:  8.15
# 	Hypothesis #47 & Reference #0:
# 		metric:	P: 12.10	R:  4.87	F1:  6.94
# 	Hypothesis #47 & Reference #1:
# 		metric:	P: 15.32	R:  5.95	F1:  8.57
# 	Hypothesis #47 & Reference #2:
# 		metric:	P: 11.46	R:  4.55	F1:  6.52
# 	Hypothesis #47 & Reference #3:
# 		metric:	P: 13.25	R:  5.20	F1:  7.47
# 	Hypothesis #48 & Reference #0:
# 		metric:	P: 16.66	R:  6.58	F1:  9.44
# 	Hypothesis #48 & Reference #1:
# 		metric:	P: 17.31	R:  6.92	F1:  9.89
# 	Hypothesis #48 & Reference #2:
# 		metric:	P: 18.18	R:  7.27	F1: 10.38
# 	Hypothesis #48 & Reference #3:
# 		metric:	P: 14.01	R:  5.47	F1:  7.87
# 	Hypothesis #49 & Reference #0:
# 		metric:	P: 12.05	R:  4.65	F1:  6.71
# 	Hypothesis #49 & Reference #1:
# 		metric:	P: 13.48	R:  5.39	F1:  7.70
# 	Hypothesis #49 & Reference #2:
# 		metric:	P:  8.82	R:  3.57	F1:  5.08
# 	Hypothesis #49 & Reference #3:
# 		metric:	P: 12.66	R:  5.12	F1:  7.29
#
#
# None
